# %%
import os
import sys
from dask.distributed import Client
client = Client(scheduler_file='/nird/home/yongyub/kimyy/Dropbox/source/python/all/mpi_nird/scheduler.json')  

def setup_module_path():
    module_path = '/nird/home/yongyub/kimyy/Dropbox/source/python/all/Modules/CESM2'
    if module_path not in sys.path:
        sys.path.append(module_path)

client.run(setup_module_path)

client
# Out:
# <Client: 'tcp://10.11.103.145:35369' processes=5 threads=160, memory=135.04 GiB>
