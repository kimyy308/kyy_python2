# %% [markdown]
# # Stable CS-White LIM: strict 7-year blocked OOS skill
#
# This version keeps the requested design:
#
# - fit the LIM to the original monthly state vector;
# - hold out four consecutive 7-year validation blocks;
# - initialize only the first 5 years of each validation block;
# - evaluate nominal leads 1–23 using centered 3-month means of forecast and observed PP.
#
# The previous draft used the finite-difference second-derivative estimate
#
# \[
# A(t)=N_2(t)N_1(t)^+,
# \]
#
# which is numerically unstable for the short, month-by-month blocked training samples. In practice,
# `N1` can be nearly singular, producing enormous eigenvalues in `A`, overflow in `expm(A*dt)`,
# and non-finite monodromy matrices.
#
# This stable version therefore uses the directly estimated one-month cyclostationary propagator
#
# \[
# G_m = K_m(1)K_m(0)^+,
# \]
#
# which is algebraically identical to direct monthly multivariate regression and was verified in the
# diagnostic test. No ad hoc covariance Fourier smoothing is applied. Optional spectral stabilization
# clips only explosive eigenvalues of the one-month propagator, preserving their phase while limiting
# their modulus.
#
# The continuous-time drift `A` is saved only as a diagnostic using `logm(G)/dt`; forecasts are made
# directly with the stabilized monthly propagators.

# %%
# ============================================================
# 0. Imports and settings
# ============================================================

import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
from scipy.linalg import expm, logm

from pathlib import Path
from datetime import date
from matplotlib.colors import BoundaryNorm, ListedColormap


LIM_FILE = Path(
    "/nird/datalake/NS11071K/users/yongyub/DD_BGC/LIM_CS/"
    "Cyclostationary_LIM_ORAS5_XRO10_GlobColour_"
    "PP_RECCAP2_all_regions_valid_zero30_1998_2025.nc"
)

OUT_DIR = Path(
    "/nird/datalake/NS11071K/users/yongyub/DD_BGC/LIM_CS/skill"
)
OUT_DIR.mkdir(parents=True, exist_ok=True)

CV_SKILL_FILE = OUT_DIR / (
    "Cyclostationary_LIM_MATLABstyle_CSWhite_PP_forecast_skill_23month_"
    "3month_running_mean_leave7yearblockout_5yearinit_"
    "corr_threshold05_RECCAP2_all_regions_valid_zero30.nc"
)

VALID_MASK_FILE = Path(
    "/nird/datalake/NS11071K/users/yongyub/Observation/GlobColour/"
    "GlobColour_PP_grid_validity_RECCAP2_all_regions/"
    "valid_mask_zero30/"
    "RECCAP2_all_regions_valid_mask_zero30_on_PPgrid.nc"
)

BLOCK_YEARS = 7
INIT_YEARS_PER_BLOCK = 5
INIT_MONTHS_PER_BLOCK = INIT_YEARS_PER_BLOCK * 12
MAX_LEAD = 23
INTERNAL_MAX_LEAD = MAX_LEAD + 1
THRESHOLD = 0.5
TARGET_STATE = "PP"
DT_YEARS = 1.0 / 12.0
FIT_MAX_LAG_MONTHS = 6

# Do not apply the earlier ad hoc Fourier smoothing to K_obs.
# The unavailable MATLAB Phase_Averaging helper is not approximated here.
APPLY_COVARIANCE_PHASE_SMOOTHING = False
PHASE_AVERAGING_FOURIER_MODES = None

# MATLAB OBS fitting sets myopt_model.FM = 2 for the seasonal model.
# Retain mean + annual + semi-annual harmonics of A(t).
A_FOURIER_MODES = 2

# A(t) = N1(t) @ pinv(N0(t)).
# Keep zero for the closest visible MATLAB-equation translation.
# Increase slightly only if covariance inversion becomes unstable.
COVARIANCE_RIDGE = 0.0
PINV_RCOND = 1.0e-10
MIN_PHASE_SAMPLES = 12

# Recommended strict rule: initialization and the complete centered
# target window must stay in the same held-out block.
STRICT_WITHIN_VALIDATION_BLOCK = True

EXCLUDE_REGIONS = [6, 18, 19, 29]
SAVE_FIGURES = False

CENTRAL_LONGITUDE = 210
PLOT_STRIDE = 4
DISPLAY_MAX_LEAD = 15

FIG_HEATMAP = OUT_DIR / (
    "LIM_CS_MATLABstyle_CSWhite_PP_leave7yearblockout_5yearinit_23month_"
    "pooled_skill_heatmap.png"
)
FIG_LINES = OUT_DIR / (
    "LIM_CS_MATLABstyle_CSWhite_PP_leave7yearblockout_5yearinit_23month_"
    "regional_skill_lines.png"
)
MAP_FIG = OUT_DIR / (
    "Map_latest_PP_skillful_lead_MATLABstyle_CSWhite_"
    "leave7yearblockout_5yearinit_23month_"
    "3month_running_mean_corr_ge_05_"
    "RECCAP2_all_regions_valid_zero30_"
    "excluding_R6_R18_R19_R29.png"
)

BASIN_SHORT = {
    "Pacific Ocean": "PO",
    "Indian Ocean": "IO",
    "Atlantic Ocean": "AO",
    "Southern Ocean": "SO",
    "Arctic Ocean": "ArO",
}

BASIN_ORDER = [
    "Pacific Ocean",
    "Indian Ocean",
    "Atlantic Ocean",
    "Southern Ocean",
    "Arctic Ocean",
]
# Stability control for monthly propagators.
# Set to None to disable spectral clipping.
MAX_ONE_MONTH_EIGENVALUE_MODULUS = 0.999

# Numerical threshold used when reconstructing stabilized propagators.
EIGENVALUE_EPS = 1.0e-12

# %%
# ============================================================
# 1. Helpers
# ============================================================

def decode_strings(values):
    return np.asarray([
        v.decode("utf-8") if isinstance(v, bytes) else str(v)
        for v in values
    ], dtype=object)


def decode_str(v):
    if isinstance(v, bytes):
        return v.decode("utf-8")
    arr = np.asarray(v)
    if arr.shape == ():
        item = arr.item()
        return item.decode("utf-8") if isinstance(item, bytes) else str(item)
    return str(v)


def corr_1d(a, b):
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)
    ok = np.isfinite(a) & np.isfinite(b)
    if ok.sum() < 3:
        return np.nan
    a = a[ok]
    b = b[ok]
    if np.std(a) == 0 or np.std(b) == 0:
        return np.nan
    return float(np.corrcoef(a, b)[0, 1])


def latest_skill_month(skill, threshold=0.5):
    skill = np.asarray(skill, dtype=float)
    good = np.where(np.isfinite(skill) & (skill >= threshold))[0]
    return 0 if good.size == 0 else int(good.max() + 1)


def build_year_blocks(times, block_years=7):
    years = pd.DatetimeIndex(pd.to_datetime(times)).year.values
    unique_years = np.unique(years)
    blocks = []

    for i0 in range(0, len(unique_years), block_years):
        fold_years = unique_years[i0:i0 + block_years]
        blocks.append({
            "fold": len(blocks),
            "years": fold_years.astype(np.int16),
            "start_year": int(fold_years[0]),
            "end_year": int(fold_years[-1]),
            "validation_mask": np.isin(years, fold_years),
        })

    return blocks


def periodic_fourier_truncate(x, max_mode=2, axis=0):
    """
    Retain the annual mean and Fourier harmonics 1...max_mode
    along a 12-phase periodic axis.

    This is the explicit Python substitute used here for the phase
    smoothing / Fourier-mode truncation called by the MATLAB workflow.
    """
    x = np.asarray(x, dtype=np.float64)

    if max_mode is None:
        return x.copy()

    nphase = x.shape[axis]
    if nphase != 12:
        raise ValueError(
            f"Expected 12 phases along axis {axis}; found {nphase}."
        )

    coeff = np.fft.fft(x, axis=axis)
    keep = np.zeros(nphase, dtype=bool)
    keep[0] = True

    max_mode = int(min(max_mode, nphase // 2))
    for k in range(1, max_mode + 1):
        keep[k] = True
        keep[-k] = True

    shape = [1] * x.ndim
    shape[axis] = nphase
    coeff = coeff * keep.reshape(shape)

    return np.fft.ifft(coeff, axis=axis).real


def compute_cs_observed_correlation(
    X,
    months,
    training_time_mask,
    maxlag=6,
    min_samples=12,
):
    """
    MATLAB-style CorrFcn_CS_Obs equivalent for held-out fitting.

    K[phase, lag] = mean{x(t+lag) x(t)^T}, with phase defined by
    the calendar month of x(t). A lagged pair is admitted only when
    the full monthly path t...t+lag belongs to the training data.

    X is already a standardized anomaly state vector, so no monthly
    intercept is fitted or added.
    """
    X = np.asarray(X, dtype=np.float64)
    months = np.asarray(months, dtype=np.int16)
    training_time_mask = np.asarray(training_time_mask, dtype=bool)

    n_time, n_state = X.shape

    K = np.full(
        (12, maxlag + 1, n_state, n_state),
        np.nan,
        dtype=np.float64,
    )
    n_samples = np.zeros(
        (12, maxlag + 1),
        dtype=np.int16,
    )

    for phase in range(1, 13):
        for lag in range(maxlag + 1):
            candidate = np.where(
                months[:n_time - lag] == phase
            )[0]

            accepted = []

            for it in candidate:
                # Prevent a covariance sample from crossing through the
                # held-out validation block.
                if not np.all(training_time_mask[it:it + lag + 1]):
                    continue

                x0 = X[it]
                x1 = X[it + lag]

                if np.isfinite(x0).all() and np.isfinite(x1).all():
                    accepted.append(it)

            n = len(accepted)
            n_samples[phase - 1, lag] = n

            if n < min_samples:
                continue

            idx = np.asarray(accepted, dtype=int)
            X0 = X[idx, :]
            X1 = X[idx + lag, :]

            # Orientation follows y = G x0:
            # K(lag) = E[x(t+lag) x(t)^T].
            K[phase - 1, lag] = (
                X1.T @ X0
            ) / n

    return K, n_samples


def _stabilize_discrete_operator(
    G,
    max_modulus=0.999,
    eigenvalue_eps=1.0e-12,
):
    """
    Spectrally stabilize a real-valued discrete propagator.

    Eigenvalue phases are retained. Only eigenvalues whose modulus exceeds
    max_modulus are radially clipped. The reconstructed real part is returned
    when the imaginary residual is numerical noise.
    """
    G = np.asarray(G, dtype=float)

    if max_modulus is None:
        return G.copy(), False, np.nan

    eigvals, eigvecs = np.linalg.eig(G)
    mod = np.abs(eigvals)
    max_before = float(np.nanmax(mod))

    scale = np.ones_like(mod, dtype=float)
    unstable = mod > max_modulus
    scale[unstable] = max_modulus / np.maximum(
        mod[unstable],
        eigenvalue_eps,
    )

    eigvals_stable = eigvals * scale

    try:
        G_stable = (
            eigvecs
            @ np.diag(eigvals_stable)
            @ np.linalg.inv(eigvecs)
        )
    except np.linalg.LinAlgError:
        # Fall back to SVD norm clipping if the eigenvector matrix is singular.
        U, s, Vt = np.linalg.svd(G, full_matrices=False)
        s = np.minimum(s, max_modulus)
        G_stable = U @ np.diag(s) @ Vt

    G_stable = np.real_if_close(G_stable, tol=1000)
    G_stable = np.asarray(np.real(G_stable), dtype=float)

    return G_stable, bool(np.any(unstable)), max_before


def fit_matlab_style_cs_white(
    X,
    months,
    training_time_mask,
    dt=1.0 / 12.0,
    maxlag=6,
    phase_average_modes=None,
    apply_covariance_phase_smoothing=False,
    a_fourier_modes=2,
    covariance_ridge=0.0,
    pinv_rcond=1.0e-10,
    min_samples=12,
    max_one_month_eigenvalue_modulus=0.999,
    eigenvalue_eps=1.0e-12,
):
    """
    Stable cyclostationary white-noise LIM.

    Main forecast operator:
        G_m = K_m(1) @ pinv(K_m(0))

    This is the discrete one-month operator and is equivalent to direct
    monthly multivariate regression. It avoids the unstable inversion of N1
    required by the finite-difference N2 @ pinv(N1) estimate.

    The N0/N1/N2 matrices and both continuous-time drift estimates are still
    saved as diagnostics.
    """
    K_raw, n_samples = compute_cs_observed_correlation(
        X=X,
        months=months,
        training_time_mask=training_time_mask,
        maxlag=maxlag,
        min_samples=min_samples,
    )

    if np.isnan(K_raw[:, :3]).any():
        raise ValueError(
            "At least one phase lacks enough lag-0/1/2 covariance samples."
        )

    if apply_covariance_phase_smoothing:
        if phase_average_modes is None:
            raise ValueError(
                "phase_average_modes must be set when covariance smoothing is enabled."
            )
        K_used = periodic_fourier_truncate(
            K_raw,
            max_mode=phase_average_modes,
            axis=0,
        )
    else:
        K_used = K_raw.copy()

    N0 = K_used[:, 0]
    N1 = (K_used[:, 1] - K_used[:, 0]) / dt
    N2 = (
        K_used[:, 0]
        - 2.0 * K_used[:, 1]
        + K_used[:, 2]
    ) / (dt ** 2)

    n_phase, n_state, _ = N0.shape

    G_one_month_raw = np.full_like(N0, np.nan)
    G_one_month = np.full_like(N0, np.nan)
    A_first_derivative_diagnostic = np.full_like(N0, np.nan)
    A_second_derivative_diagnostic = np.full_like(N0, np.nan)

    was_stabilized = np.zeros(12, dtype=bool)
    max_eig_before = np.full(12, np.nan)

    for iphase in range(n_phase):
        C0 = N0[iphase].copy()
        D1 = N1[iphase].copy()

        if covariance_ridge > 0:
            scale_c0 = np.trace(C0) / n_state
            if not np.isfinite(scale_c0) or scale_c0 <= 0:
                scale_c0 = 1.0
            C0 = (
                C0
                + covariance_ridge
                * scale_c0
                * np.eye(n_state)
            )

            scale_d1 = np.linalg.norm(D1, ord="fro") / max(n_state, 1)
            if not np.isfinite(scale_d1) or scale_d1 <= 0:
                scale_d1 = 1.0
            D1 = (
                D1
                + covariance_ridge
                * scale_d1
                * np.eye(n_state)
            )

        G_raw = (
            K_used[iphase, 1]
            @ np.linalg.pinv(
                C0,
                rcond=pinv_rcond,
            )
        )

        G_stable, clipped, max_before = _stabilize_discrete_operator(
            G_raw,
            max_modulus=max_one_month_eigenvalue_modulus,
            eigenvalue_eps=eigenvalue_eps,
        )

        G_one_month_raw[iphase] = G_raw
        G_one_month[iphase] = G_stable
        was_stabilized[iphase] = clipped
        max_eig_before[iphase] = max_before

        A_first_derivative_diagnostic[iphase] = (
            N1[iphase]
            @ np.linalg.pinv(
                C0,
                rcond=pinv_rcond,
            )
        )

        try:
            A_second_derivative_diagnostic[iphase] = (
                N2[iphase]
                @ np.linalg.pinv(
                    D1,
                    rcond=pinv_rcond,
                )
            )
        except np.linalg.LinAlgError:
            A_second_derivative_diagnostic[iphase] = np.nan

    # Continuous-time A is diagnostic only. Forecasts use G_one_month directly.
    A = np.full_like(G_one_month, np.nan)
    for iphase in range(12):
        try:
            A_complex = logm(G_one_month[iphase]) / dt
            A[iphase] = np.real_if_close(
                A_complex,
                tol=1000,
            ).real
        except Exception:
            A[iphase] = np.nan

    # Safe monodromy diagnostic.
    monodromy = np.eye(n_state)
    monodromy_is_finite = True

    for iphase in range(12):
        monodromy = G_one_month[iphase] @ monodromy
        if not np.isfinite(monodromy).all():
            monodromy_is_finite = False
            break

    if monodromy_is_finite:
        try:
            max_floquet_modulus = float(
                np.max(
                    np.abs(
                        np.linalg.eigvals(monodromy)
                    )
                )
            )
        except np.linalg.LinAlgError:
            max_floquet_modulus = np.nan
    else:
        max_floquet_modulus = np.nan

    return {
        "K_raw": K_raw,
        "K_used": K_used,
        "N0": N0,
        "N1": N1,
        "N2": N2,
        "A": A,
        "A_first_derivative_diagnostic": A_first_derivative_diagnostic,
        "A_second_derivative_diagnostic": A_second_derivative_diagnostic,
        "G_one_month_raw": G_one_month_raw,
        "G_one_month": G_one_month,
        "n_samples": n_samples,
        "was_stabilized": was_stabilized,
        "max_one_month_eigenvalue_modulus_before": max_eig_before,
        "max_floquet_modulus": max_floquet_modulus,
    }

def cs_white_evolution_operators(
    G_one_month,
    max_lead,
):
    """
    Ordered cyclostationary evolution operators.

    output[start_phase, lead] maps x(t) to x(t+lead).
    Lead zero is the identity.
    """
    G_one_month = np.asarray(
        G_one_month,
        dtype=np.float64,
    )

    n_state = G_one_month.shape[-1]

    evolution = np.full(
        (12, max_lead + 1, n_state, n_state),
        np.nan,
        dtype=np.float64,
    )

    for start_phase in range(12):
        current = np.eye(n_state)
        evolution[start_phase, 0] = current

        for lead in range(1, max_lead + 1):
            step_phase = (
                start_phase + lead - 1
            ) % 12

            current = (
                G_one_month[step_phase]
                @ current
            )

            evolution[start_phase, lead] = current

    return evolution


def forecast_matlab_style_cs_white(
    X,
    months,
    init_indices,
    evolution,
    max_lead,
):
    """
    Deterministic MATLAB-style forecast:
        y = G_CS_White(start_phase, lead) @ x0

    No fitted intercept or fold-specific mean is added.
    """
    X = np.asarray(X, dtype=np.float64)
    init_indices = np.asarray(init_indices, dtype=int)

    n_state = X.shape[1]

    Xhat = np.full(
        (
            len(init_indices),
            max_lead + 1,
            n_state,
        ),
        np.nan,
        dtype=np.float64,
    )

    for j, it in enumerate(init_indices):
        x0 = X[it].copy()

        if not np.isfinite(x0).all():
            continue

        start_phase = int(months[it] - 1)

        for lead in range(max_lead + 1):
            G = evolution[start_phase, lead]

            if np.isfinite(G).all():
                Xhat[j, lead] = G @ x0

    return Xhat




def centered_mean_3_timeseries(x):
    """At t, mean of t-1, t, t+1; strict NaN handling."""
    x = np.asarray(x, dtype=np.float64)
    out = np.full(x.shape, np.nan, dtype=np.float64)
    if x.size < 3:
        return out
    window = np.stack([x[:-2], x[1:-1], x[2:]], axis=1)
    good = np.isfinite(window).all(axis=1)
    out[np.where(good)[0] + 1] = window[good].mean(axis=1)
    return out


def centered_mean_3_forecast(pp_raw, max_lead):
    """Nominal lead L averages raw forecast leads L-1, L, L+1."""
    pp_raw = np.asarray(pp_raw, dtype=np.float64)
    if pp_raw.ndim != 2 or pp_raw.shape[1] < max_lead + 2:
        raise ValueError(
            f"Forecast must include lead 0 through {max_lead + 1}; "
            f"received {pp_raw.shape}."
        )

    out = np.full((pp_raw.shape[0], max_lead), np.nan, dtype=np.float64)
    for lead in range(1, max_lead + 1):
        window = pp_raw[:, lead - 1:lead + 2]
        good = np.isfinite(window).all(axis=1)
        out[good, lead - 1] = window[good].mean(axis=1)
    return out


def get_region_label(ds, reg, short=True):
    reg = int(reg)
    try:
        name = decode_str(ds["region_name"].sel(region=reg).values)
    except Exception:
        name = f"region {reg}"
    try:
        basin = decode_str(ds["basin"].sel(region=reg).values)
    except Exception:
        basin = ""
    try:
        original_id = int(ds["original_region_id"].sel(region=reg).values)
    except Exception:
        original_id = -999

    if short:
        return f"R{reg}. {name}"
    if basin and original_id > 0:
        return f"R{reg}. {basin}:{original_id} {name}"
    return f"R{reg}. {name}"


def get_basin_name(ds, reg):
    try:
        raw = decode_str(ds["basin"].sel(region=int(reg)).values).strip()
    except Exception:
        return "Unknown"
    name = raw.lower()
    if "pacific" in name:
        return "Pacific Ocean"
    if "indian" in name:
        return "Indian Ocean"
    if "atlantic" in name:
        return "Atlantic Ocean"
    if "southern" in name:
        return "Southern Ocean"
    if "arctic" in name:
        return "Arctic Ocean"
    return raw


def lon_to_180(lon):
    return ((lon + 180.0) % 360.0) - 180.0


def weighted_centroid(lon, lat, mask):
    lon2d, lat2d = np.meshgrid(lon, lat)
    weights = np.where(mask, np.cos(np.deg2rad(lat2d)), 0.0)
    wsum = np.nansum(weights)
    if wsum <= 0:
        return np.nan, np.nan
    lon_rad = np.deg2rad(lon2d)
    x = np.nansum(weights * np.cos(lon_rad)) / wsum
    y = np.nansum(weights * np.sin(lon_rad)) / wsum
    lon_c = np.rad2deg(np.arctan2(y, x)) % 360.0
    lat_c = np.nansum(weights * lat2d) / wsum
    return lon_c, lat_c


def add_cyclic_manual(data, lon):
    lon = np.asarray(lon, dtype=np.float64)
    sort_idx = np.argsort(lon)
    lon_sorted = lon[sort_idx]
    data_sorted = data[:, sort_idx]
    dlon = float(np.nanmedian(np.diff(lon_sorted)))
    lon_cyc = np.concatenate([lon_sorted, [lon_sorted[-1] + dlon]])
    data_cyc = np.concatenate([data_sorted, data_sorted[:, :1]], axis=1)
    return data_cyc, lon_cyc

# %%
# ============================================================
# 2. Blocked cross-validation fitting and forecasts
# ============================================================

if not LIM_FILE.exists():
    raise FileNotFoundError(f"LIM file not found:\n{LIM_FILE}")

with xr.open_dataset(LIM_FILE) as ds:
    ds_lim = ds.load()

if "state_vector" not in ds_lim:
    raise KeyError(f"state_vector not found in:\n{LIM_FILE}")

state_vector = ds_lim["state_vector"].transpose("region", "time", "state")
regions = state_vector.region.values.astype(np.int16)
times = state_vector.time.values
states = decode_strings(state_vector.state.values)
months = pd.DatetimeIndex(pd.to_datetime(times)).month.values.astype(np.int16)

match = np.where(states == TARGET_STATE)[0]
if match.size != 1:
    raise ValueError(f"TARGET_STATE={TARGET_STATE!r} not unique: {list(states)}")
target_idx = int(match[0])

n_region = len(regions)
n_time = len(times)
lead_coord = np.arange(1, MAX_LEAD + 1, dtype=np.int16)
init_month_coord = np.arange(1, 13, dtype=np.int16)

folds = build_year_blocks(times, BLOCK_YEARS)
n_fold = len(folds)
fold_id_for_time = np.full(n_time, -1, dtype=np.int16)
validation_init_mask = np.zeros(n_time, dtype=bool)

for fold in folds:
    fold_indices = np.where(fold["validation_mask"])[0]

    if len(fold_indices) != BLOCK_YEARS * 12:
        raise ValueError(
            f"Fold {fold['fold']} contains {len(fold_indices)} months; "
            f"expected {BLOCK_YEARS * 12}. "
            "This notebook assumes four complete 7-year blocks."
        )

    init_indices = fold_indices[:INIT_MONTHS_PER_BLOCK]
    fold["init_indices"] = init_indices

    fold_id_for_time[fold_indices] = fold["fold"]
    validation_init_mask[init_indices] = True

if np.any(fold_id_for_time < 0):
    raise RuntimeError("Some months were not assigned to a validation fold.")

print("Validation folds:")
for fold in folds:
    text = ", ".join(str(int(y)) for y in fold["years"])
    init_dates = pd.DatetimeIndex(pd.to_datetime(times[fold["init_indices"]]))
    print(
        f"  fold {fold['fold']:02d}: {text} "
        f"({fold['validation_mask'].sum()} validation months); "
        f"initializations {init_dates[0].strftime('%Y-%m')} to "
        f"{init_dates[-1].strftime('%Y-%m')} "
        f"({len(fold['init_indices'])} months)"
    )

pp_prediction_oos = np.full(
    (n_region, n_time, MAX_LEAD),
    np.nan,
    dtype=np.float32,
)

n_training_samples = np.zeros(
    (n_region, n_fold, 12, FIT_MAX_LAG_MONTHS + 1),
    dtype=np.int16,
)

A_cs_white = np.full(
    (n_region, n_fold, 12, len(states), len(states)),
    np.nan,
    dtype=np.float32,
)

G1_cs_white = np.full_like(
    A_cs_white,
    np.nan,
)

max_floquet_modulus = np.full(
    (n_region, n_fold),
    np.nan,
    dtype=np.float32,
)


for ir, reg in enumerate(regions):
    print(
        f"[{ir + 1:02d}/{n_region:02d}] "
        f"region {int(reg)}"
    )

    X = (
        state_vector
        .sel(region=reg)
        .values
        .astype(np.float64)
    )

    for fold in folds:
        ifold = fold["fold"]
        validation_mask = fold["validation_mask"]
        training_mask = ~validation_mask
        init_idx_fold = fold["init_indices"]

        fit = fit_matlab_style_cs_white(
            X=X,
            months=months,
            training_time_mask=training_mask,
            dt=DT_YEARS,
            maxlag=FIT_MAX_LAG_MONTHS,
            phase_average_modes=PHASE_AVERAGING_FOURIER_MODES,
            apply_covariance_phase_smoothing=APPLY_COVARIANCE_PHASE_SMOOTHING,
            a_fourier_modes=A_FOURIER_MODES,
            covariance_ridge=COVARIANCE_RIDGE,
            pinv_rcond=PINV_RCOND,
            min_samples=MIN_PHASE_SAMPLES,
            max_one_month_eigenvalue_modulus=MAX_ONE_MONTH_EIGENVALUE_MODULUS,
            eigenvalue_eps=EIGENVALUE_EPS,
        )

        n_training_samples[ir, ifold] = fit["n_samples"]
        A_cs_white[ir, ifold] = fit["A"].astype(np.float32)
        G1_cs_white[ir, ifold] = fit["G_one_month"].astype(np.float32)
        max_floquet_modulus[ir, ifold] = fit["max_floquet_modulus"]
        n_clipped = int(np.sum(fit["was_stabilized"]))
        max_raw_eig = float(
            np.nanmax(
                fit["max_one_month_eigenvalue_modulus_before"]
            )
        )

        print(
            f"  fold {ifold}: "
            f"max raw monthly |eig| = {max_raw_eig:.3f}; "
            f"clipped months = {n_clipped}/12; "
            f"max Floquet modulus = {fit['max_floquet_modulus']:.3f}"
        )


        evolution = cs_white_evolution_operators(
            fit["G_one_month"],
            max_lead=INTERNAL_MAX_LEAD,
        )

        Xhat = forecast_matlab_style_cs_white(
            X=X,
            months=months,
            init_indices=init_idx_fold,
            evolution=evolution,
            max_lead=INTERNAL_MAX_LEAD,
        )

        pred_3mon = centered_mean_3_forecast(
            Xhat[:, :, target_idx],
            MAX_LEAD,
        )

        for j, it in enumerate(init_idx_fold):
            for lead in range(1, MAX_LEAD + 1):
                target = it + lead

                if target - 1 < 0 or target + 1 >= n_time:
                    continue

                if STRICT_WITHIN_VALIDATION_BLOCK:
                    required = np.asarray(
                        [it, target - 1, target, target + 1],
                        dtype=int,
                    )

                    if not np.all(
                        fold_id_for_time[required] == ifold
                    ):
                        continue

                value = pred_3mon[j, lead - 1]

                if np.isfinite(value):
                    pp_prediction_oos[
                        ir,
                        it,
                        lead - 1,
                    ] = value
# Out:
# Validation folds:
#   fold 00: 1998, 1999, 2000, 2001, 2002, 2003, 2004 (84 validation months); initializations 1998-01 to 2002-12 (60 months)
#   fold 01: 2005, 2006, 2007, 2008, 2009, 2010, 2011 (84 validation months); initializations 2005-01 to 2009-12 (60 months)
#   fold 02: 2012, 2013, 2014, 2015, 2016, 2017, 2018 (84 validation months); initializations 2012-01 to 2016-12 (60 months)
#   fold 03: 2019, 2020, 2021, 2022, 2023, 2024, 2025 (84 validation months); initializations 2019-01 to 2023-12 (60 months)
# [01/21] region 1
#   fold 0: max raw monthly |eig| = 1.940; clipped months = 12/12; max Floquet modulus = 0.309
#   fold 1: max raw monthly |eig| = 2.723; clipped months = 12/12; max Floquet modulus = 0.383
#   fold 2: max raw monthly |eig| = 2.317; clipped months = 12/12; max Floquet modulus = 0.326
#   fold 3: max raw monthly |eig| = 1.997; clipped months = 12/12; max Floquet modulus = 0.249
# [02/21] region 2
#   fold 0: max raw monthly |eig| = 1.922; clipped months = 12/12; max Floquet modulus = 0.506
#   fold 1: max raw monthly |eig| = 2.792; clipped months = 11/12; max Floquet modulus = 0.288
#   fold 2: max raw monthly |eig| = 2.187; clipped months = 12/12; max Floquet modulus = 0.297
#   fold 3: max raw monthly |eig| = 1.712; clipped months = 12/12; max Floquet modulus = 0.267
# [03/21] region 3
#   fold 0: max raw monthly |eig| = 1.846; clipped months = 12/12; max Floquet modulus = 0.349
#   fold 1: max raw monthly |eig| = 2.792; clipped months = 12/12; max Floquet modulus = 0.354
#   fold 2: max raw monthly |eig| = 2.453; clipped months = 12/12; max Floquet modulus = 0.301
#   fold 3: max raw monthly |eig| = 1.664; clipped months = 12/12; max Floquet modulus = 0.314
# [04/21] region 4
#   fold 0: max raw monthly |eig| = 1.850; clipped months = 12/12; max Floquet modulus = 0.414
#   fold 1: max raw monthly |eig| = 2.731; clipped months = 12/12; max Floquet modulus = 0.435
#   fold 2: max raw monthly |eig| = 2.195; clipped months = 12/12; max Floquet modulus = 0.341
#   fold 3: max raw monthly |eig| = 1.588; clipped months = 12/12; max Floquet modulus = 0.409
# [05/21] region 5
#   fold 0: max raw monthly |eig| = 2.141; clipped months = 12/12; max Floquet modulus = 0.369
#   fold 1: max raw monthly |eig| = 2.991; clipped months = 11/12; max Floquet modulus = 0.253
#   fold 2: max raw monthly |eig| = 2.098; clipped months = 12/12; max Floquet modulus = 0.250
#   fold 3: max raw monthly |eig| = 1.583; clipped months = 12/12; max Floquet modulus = 0.221
# [06/21] region 6
#   fold 0: max raw monthly |eig| = 1.952; clipped months = 12/12; max Floquet modulus = 0.403
#   fold 1: max raw monthly |eig| = 2.772; clipped months = 12/12; max Floquet modulus = 0.453
#   fold 2: max raw monthly |eig| = 2.377; clipped months = 12/12; max Floquet modulus = 0.313
#   fold 3: max raw monthly |eig| = 2.053; clipped months = 12/12; max Floquet modulus = 0.178
# [07/21] region 7
#   fold 0: max raw monthly |eig| = 1.875; clipped months = 12/12; max Floquet modulus = 0.394
#   fold 1: max raw monthly |eig| = 2.729; clipped months = 12/12; max Floquet modulus = 0.323
#   fold 2: max raw monthly |eig| = 2.202; clipped months = 12/12; max Floquet modulus = 0.325
#   fold 3: max raw monthly |eig| = 1.480; clipped months = 12/12; max Floquet modulus = 0.179
# [08/21] region 8
#   fold 0: max raw monthly |eig| = 1.633; clipped months = 12/12; max Floquet modulus = 0.413
#   fold 1: max raw monthly |eig| = 2.783; clipped months = 12/12; max Floquet modulus = 0.311
#   fold 2: max raw monthly |eig| = 2.241; clipped months = 12/12; max Floquet modulus = 0.274
#   fold 3: max raw monthly |eig| = 1.546; clipped months = 12/12; max Floquet modulus = 0.687
# [09/21] region 9
#   fold 0: max raw monthly |eig| = 1.673; clipped months = 12/12; max Floquet modulus = 0.365
#   fold 1: max raw monthly |eig| = 1.876; clipped months = 12/12; max Floquet modulus = 0.392
#   fold 2: max raw monthly |eig| = 2.204; clipped months = 12/12; max Floquet modulus = 0.309
#   fold 3: max raw monthly |eig| = 1.562; clipped months = 11/12; max Floquet modulus = 0.335
# [10/21] region 10
#   fold 0: max raw monthly |eig| = 1.651; clipped months = 12/12; max Floquet modulus = 0.372
#   fold 1: max raw monthly |eig| = 2.745; clipped months = 11/12; max Floquet modulus = 0.384
#   fold 2: max raw monthly |eig| = 2.187; clipped months = 12/12; max Floquet modulus = 0.294
#   fold 3: max raw monthly |eig| = 1.648; clipped months = 12/12; max Floquet modulus = 0.609
# [11/21] region 11
#   fold 0: max raw monthly |eig| = 1.919; clipped months = 12/12; max Floquet modulus = 0.309
#   fold 1: max raw monthly |eig| = 2.481; clipped months = 12/12; max Floquet modulus = 0.228
#   fold 2: max raw monthly |eig| = 2.294; clipped months = 12/12; max Floquet modulus = 0.300
#   fold 3: max raw monthly |eig| = 1.640; clipped months = 12/12; max Floquet modulus = 0.174
# [12/21] region 12
#   fold 0: max raw monthly |eig| = 1.736; clipped months = 12/12; max Floquet modulus = 0.336
#   fold 1: max raw monthly |eig| = 2.708; clipped months = 11/12; max Floquet modulus = 0.345
#   fold 2: max raw monthly |eig| = 2.183; clipped months = 12/12; max Floquet modulus = 0.306
#   fold 3: max raw monthly |eig| = 1.516; clipped months = 12/12; max Floquet modulus = 0.280
# [13/21] region 13
#   fold 0: max raw monthly |eig| = 1.793; clipped months = 12/12; max Floquet modulus = 0.343
#   fold 1: max raw monthly |eig| = 2.925; clipped months = 12/12; max Floquet modulus = 0.325
#   fold 2: max raw monthly |eig| = 2.162; clipped months = 12/12; max Floquet modulus = 0.250
#   fold 3: max raw monthly |eig| = 1.768; clipped months = 12/12; max Floquet modulus = 0.314
# [14/21] region 14
#   fold 0: max raw monthly |eig| = 1.962; clipped months = 12/12; max Floquet modulus = 0.382
#   fold 1: max raw monthly |eig| = 3.812; clipped months = 12/12; max Floquet modulus = 0.356
#   fold 2: max raw monthly |eig| = 2.270; clipped months = 12/12; max Floquet modulus = 0.317
#   fold 3: max raw monthly |eig| = 1.752; clipped months = 12/12; max Floquet modulus = 0.318
# [15/21] region 15
#   fold 0: max raw monthly |eig| = 2.036; clipped months = 12/12; max Floquet modulus = 0.395
#   fold 1: max raw monthly |eig| = 2.703; clipped months = 12/12; max Floquet modulus = 0.356
#   fold 2: max raw monthly |eig| = 2.230; clipped months = 12/12; max Floquet modulus = 0.286
#   fold 3: max raw monthly |eig| = 1.627; clipped months = 12/12; max Floquet modulus = 0.255
# [16/21] region 16
#   fold 0: max raw monthly |eig| = 1.942; clipped months = 12/12; max Floquet modulus = 0.395
#   fold 1: max raw monthly |eig| = 2.715; clipped months = 12/12; max Floquet modulus = 0.353
#   fold 2: max raw monthly |eig| = 1.983; clipped months = 12/12; max Floquet modulus = 0.314
#   fold 3: max raw monthly |eig| = 1.775; clipped months = 12/12; max Floquet modulus = 0.446
# [17/21] region 18
#   fold 0: max raw monthly |eig| = 8.462; clipped months = 12/12; max Floquet modulus = 0.403
#   fold 1: max raw monthly |eig| = 2.698; clipped months = 12/12; max Floquet modulus = 0.387
#   fold 2: max raw monthly |eig| = 12.122; clipped months = 12/12; max Floquet modulus = 0.334
#   fold 3: max raw monthly |eig| = 3.510; clipped months = 12/12; max Floquet modulus = 0.200
# [18/21] region 19
#   fold 0: max raw monthly |eig| = 1.725; clipped months = 12/12; max Floquet modulus = 0.335
#   fold 1: max raw monthly |eig| = 2.698; clipped months = 11/12; max Floquet modulus = 0.311
#   fold 2: max raw monthly |eig| = 2.531; clipped months = 12/12; max Floquet modulus = 0.303
#   fold 3: max raw monthly |eig| = 1.801; clipped months = 12/12; max Floquet modulus = 0.205
# [19/21] region 27
#   fold 0: max raw monthly |eig| = 1.870; clipped months = 12/12; max Floquet modulus = 0.383
#   fold 1: max raw monthly |eig| = 3.020; clipped months = 12/12; max Floquet modulus = 0.309
#   fold 2: max raw monthly |eig| = 2.190; clipped months = 12/12; max Floquet modulus = 0.196
#   fold 3: max raw monthly |eig| = 1.620; clipped months = 12/12; max Floquet modulus = 0.277
# [20/21] region 28
#   fold 0: max raw monthly |eig| = 1.758; clipped months = 12/12; max Floquet modulus = 0.343
#   fold 1: max raw monthly |eig| = 2.889; clipped months = 12/12; max Floquet modulus = 0.386
#   fold 2: max raw monthly |eig| = 2.269; clipped months = 12/12; max Floquet modulus = 0.280
#   fold 3: max raw monthly |eig| = 1.738; clipped months = 12/12; max Floquet modulus = 0.271
# [21/21] region 29
#   fold 0: max raw monthly |eig| = 1.784; clipped months = 12/12; max Floquet modulus = 0.464
#   fold 1: max raw monthly |eig| = 2.636; clipped months = 12/12; max Floquet modulus = 0.377
#   fold 2: max raw monthly |eig| = 2.262; clipped months = 12/12; max Floquet modulus = 0.297
#   fold 3: max raw monthly |eig| = 2.368; clipped months = 12/12; max Floquet modulus = 0.340

# %%
# ============================================================
# 3. Pooled out-of-sample skill and netCDF output
# ============================================================

pp_corr = np.full((n_region, MAX_LEAD), np.nan, dtype=np.float64)
n_pairs = np.zeros((n_region, MAX_LEAD), dtype=np.int16)
pp_corr_by_init_month = np.full((n_region, 12, MAX_LEAD), np.nan)
n_pairs_by_init_month = np.zeros((n_region, 12, MAX_LEAD), dtype=np.int16)
pp_corr_by_fold = np.full((n_region, n_fold, MAX_LEAD), np.nan)
n_pairs_by_fold = np.zeros((n_region, n_fold, MAX_LEAD), dtype=np.int16)

for ir, reg in enumerate(regions):
    X = state_vector.sel(region=reg).values.astype(np.float64)
    obs_3mon = centered_mean_3_timeseries(X[:, target_idx])

    common_init_idx = np.where(validation_init_mask)[0]

    for lead in range(1, MAX_LEAD + 1):
        # Use exactly the same held-out initialization months at every lead.
        init_idx = common_init_idx
        target = init_idx + lead
        pred = pp_prediction_oos[ir, init_idx, lead - 1]
        obs = obs_3mon[target]

        ok = np.isfinite(pred) & np.isfinite(obs)
        n_pairs[ir, lead - 1] = int(ok.sum())
        pp_corr[ir, lead - 1] = corr_1d(pred, obs)

        for init_month in range(1, 13):
            choose = months[init_idx] == init_month
            pred_m = pred[choose]
            obs_m = obs[choose]
            ok_m = np.isfinite(pred_m) & np.isfinite(obs_m)
            n_pairs_by_init_month[ir, init_month - 1, lead - 1] = int(ok_m.sum())
            pp_corr_by_init_month[ir, init_month - 1, lead - 1] = corr_1d(pred_m, obs_m)

        for ifold in range(n_fold):
            choose = fold_id_for_time[init_idx] == ifold
            pred_f = pred[choose]
            obs_f = obs[choose]
            ok_f = np.isfinite(pred_f) & np.isfinite(obs_f)
            n_pairs_by_fold[ir, ifold, lead - 1] = int(ok_f.sum())
            pp_corr_by_fold[ir, ifold, lead - 1] = corr_1d(pred_f, obs_f)

latest_lead = np.array(
    [latest_skill_month(pp_corr[ir], THRESHOLD) for ir in range(n_region)],
    dtype=np.int16,
)
latest_by_month = np.zeros((n_region, 12), dtype=np.int16)
for ir in range(n_region):
    for im in range(12):
        latest_by_month[ir, im] = latest_skill_month(
            pp_corr_by_init_month[ir, im], THRESHOLD
        )

region_name_values = (
    decode_strings(ds_lim["region_name"].sel(region=regions).values)
    if "region_name" in ds_lim
    else np.asarray([f"region {int(r)}" for r in regions], dtype=object)
)
basin_values = (
    decode_strings(ds_lim["basin"].sel(region=regions).values)
    if "basin" in ds_lim
    else np.asarray([""] * n_region, dtype=object)
)
original_region_id_values = (
    ds_lim["original_region_id"].sel(region=regions).values.astype(np.int16)
    if "original_region_id" in ds_lim
    else np.full(n_region, -999, dtype=np.int16)
)

fold_start_year = np.array([f["start_year"] for f in folds], dtype=np.int16)
fold_end_year = np.array([f["end_year"] for f in folds], dtype=np.int16)
fold_n_years = np.array([len(f["years"]) for f in folds], dtype=np.int16)
fold_n_months = np.array([f["validation_mask"].sum() for f in folds], dtype=np.int16)

ds_cv = xr.Dataset(
    data_vars={
        "PP_prediction": (
            ("region", "init_time", "lead"),
            pp_prediction_oos,
            {
                "long_name": "Out-of-sample centered 3-month PP prediction",
                "description": "Nominal lead L averages raw leads L-1, L, and L+1.",
                "units": "standard deviation",
            },
        ),
        "PP_correlation_skill": (
            ("region", "lead"),
            pp_corr.astype(np.float32),
            {"long_name": "Leave-7-year-block-out centered 3-month PP correlation skill"},
        ),
        "PP_correlation_skill_by_init_month": (
            ("region", "init_month", "lead"),
            pp_corr_by_init_month.astype(np.float32),
        ),
        "PP_correlation_skill_by_fold": (
            ("region", "validation_fold", "lead"),
            pp_corr_by_fold.astype(np.float32),
            {"warning": "Individual fold skill can be noisy because each block is short."},
        ),
        "n_pairs": (("region", "lead"), n_pairs),
        "n_pairs_by_init_month": (
            ("region", "init_month", "lead"), n_pairs_by_init_month
        ),
        "n_pairs_by_fold": (
            ("region", "validation_fold", "lead"), n_pairs_by_fold
        ),
        "n_training_samples": (
            ("region", "validation_fold", "month", "fit_lag"),
            n_training_samples,
            {
                "long_name": (
                    "Number of training covariance samples by phase and lag"
                ),
            },
        ),
        "A_CS_White": (
            (
                "region",
                "validation_fold",
                "month",
                "state_to",
                "state_from",
            ),
            A_cs_white,
            {
                "long_name": (
                    "MATLAB-style continuous-time CS-White drift matrix"
                ),
                "units": "year-1",
            },
        ),
        "G1_CS_White": (
            (
                "region",
                "validation_fold",
                "month",
                "state_to",
                "state_from",
            ),
            G1_cs_white,
            {
                "long_name": (
                    "One-month CS-White evolution operator exp(A dt)"
                ),
            },
        ),
        "max_floquet_modulus": (
            ("region", "validation_fold"),
            max_floquet_modulus,
            {
                "long_name": (
                    "Maximum absolute eigenvalue of the annual monodromy matrix"
                ),
                "description": (
                    "Values below one indicate a stable annual deterministic cycle."
                ),
            },
        ),
        "latest_lead_corr_ge_05": (
            ("region",),
            latest_lead,
            {"long_name": "Latest OOS lead with centered 3-month PP correlation >= 0.5", "units": "month"},
        ),
        "latest_lead_corr_ge_05_by_init_month": (
            ("region", "init_month"), latest_by_month
        ),
        "validation_fold_for_time": (("init_time",), fold_id_for_time),
        "used_as_validation_initialization": (
            ("init_time",),
            validation_init_mask.astype(np.int8),
            {
                "long_name": "Month used as a held-out forecast initialization",
                "description": (
                    "One for the first 60 months of each 7-year held-out block; "
                    "zero otherwise."
                ),
            },
        ),
        "fold_start_year": (("validation_fold",), fold_start_year),
        "fold_end_year": (("validation_fold",), fold_end_year),
        "fold_n_years": (("validation_fold",), fold_n_years),
        "fold_n_months": (("validation_fold",), fold_n_months),
        "region_name": (("region",), region_name_values.astype(object)),
        "basin": (("region",), basin_values.astype(object)),
        "original_region_id": (("region",), original_region_id_values),
    },
    coords={
        "region": regions,
        "init_time": times,
        "lead": lead_coord,
        "init_month": init_month_coord,
        "validation_fold": np.arange(n_fold, dtype=np.int16),
        "month": np.arange(1, 13, dtype=np.int16),
        "fit_lag": np.arange(
            0,
            FIT_MAX_LAG_MONTHS + 1,
            dtype=np.int16,
        ),
        "state_to": states,
        "state_from": states,
    },
    attrs={
        "title": "Stable CS-White blocked OOS centered 3-month PP skill",
        "state_vector_source_file": str(LIM_FILE),
        "cross_validation": (
            "Four consecutive non-overlapping leave-7-year-block-out folds. "
            "Only the first five years (60 months) of each held-out block "
            "are used as forecast initializations."
        ),
        "strict_within_validation_block": str(STRICT_WITHIN_VALIDATION_BLOCK),
        "training_covariance_rule": (
            "For K(t,lag), every month from t through t+lag must be outside "
            "the validation block."
        ),
        "verification_rule": (
            "All leads use the same 60 initialization months per fold. "
            "Initialization and target-1,target,target+1 remain inside the "
            "same held-out 7-year block."
        ),
        "initialization_years_per_fold": INIT_YEARS_PER_BLOCK,
        "initialization_months_per_fold": INIT_MONTHS_PER_BLOCK,
        "running_mean_alignment": "centered",
        "running_mean_months": 3,
        "max_nominal_lead_months": MAX_LEAD,
        "correlation_threshold": THRESHOLD,
        "lim_model": "stable discrete cyclostationary white-noise LIM",
        "forecast_operator": "G_month = K_month(lag=1) @ pinv(K_month(lag=0))",
        "forecast_equation": "xhat(t+lead) = G_CS_White(t,lead) @ x(t)",
        "dt_years": DT_YEARS,
        "fit_max_lag_months": FIT_MAX_LAG_MONTHS,
        "covariance_phase_smoothing_applied": str(APPLY_COVARIANCE_PHASE_SMOOTHING),
        "phase_averaging_fourier_modes": str(PHASE_AVERAGING_FOURIER_MODES),
        "A_fourier_modes": A_FOURIER_MODES,
        "covariance_ridge": COVARIANCE_RIDGE,
        "pinv_rcond": PINV_RCOND,
        "min_phase_samples": MIN_PHASE_SAMPLES,
        "important_note": (
            "The original monthly state vector is used for fitting and centered "
            "3-month means are applied only during verification. Forecasts use "
            "the direct monthly covariance-regression propagator. Explosive "
            "one-month eigenvalues are optionally clipped for numerical stability."
        ),
        "date_created": date.today().isoformat(),
    },
)

encoding = {
    "PP_prediction": {"dtype": "float32", "_FillValue": np.float32(-999), "zlib": True, "complevel": 4},
    "PP_correlation_skill": {"dtype": "float32", "_FillValue": np.float32(-999), "zlib": True, "complevel": 4},
    "PP_correlation_skill_by_init_month": {"dtype": "float32", "_FillValue": np.float32(-999), "zlib": True, "complevel": 4},
    "PP_correlation_skill_by_fold": {"dtype": "float32", "_FillValue": np.float32(-999), "zlib": True, "complevel": 4},
    "n_pairs": {"dtype": "int16", "_FillValue": None},
    "n_pairs_by_init_month": {"dtype": "int16", "_FillValue": None},
    "n_pairs_by_fold": {"dtype": "int16", "_FillValue": None},
    "n_training_samples": {"dtype": "int16", "_FillValue": None},
    "A_CS_White": {
        "dtype": "float32",
        "_FillValue": np.float32(-999),
        "zlib": True,
        "complevel": 4,
    },
    "G1_CS_White": {
        "dtype": "float32",
        "_FillValue": np.float32(-999),
        "zlib": True,
        "complevel": 4,
    },
    "max_floquet_modulus": {
        "dtype": "float32",
        "_FillValue": np.float32(-999),
    },
    "latest_lead_corr_ge_05": {"dtype": "int16", "_FillValue": None},
    "latest_lead_corr_ge_05_by_init_month": {"dtype": "int16", "_FillValue": None},
    "validation_fold_for_time": {"dtype": "int16", "_FillValue": None},
    "used_as_validation_initialization": {"dtype": "int8", "_FillValue": None},
    "fold_start_year": {"dtype": "int16", "_FillValue": None},
    "fold_end_year": {"dtype": "int16", "_FillValue": None},
    "fold_n_years": {"dtype": "int16", "_FillValue": None},
    "fold_n_months": {"dtype": "int16", "_FillValue": None},
    "original_region_id": {"dtype": "int16", "_FillValue": None},
    "region": {"dtype": "int16", "_FillValue": None},
    "lead": {"dtype": "int16", "_FillValue": None},
    "init_month": {"dtype": "int16", "_FillValue": None},
    "validation_fold": {"dtype": "int16", "_FillValue": None},
    "month": {"dtype": "int16", "_FillValue": None},
    "fit_lag": {"dtype": "int16", "_FillValue": None},
    "init_time": {"dtype": "float64", "units": "days since 1900-01-01", "calendar": "gregorian"},
}

if CV_SKILL_FILE.exists():
    CV_SKILL_FILE.unlink()

ds_cv.to_netcdf(CV_SKILL_FILE, encoding=encoding, engine="netcdf4")
print(f"Saved: {CV_SKILL_FILE}")
print(ds_cv)
# Out:
# Saved: /nird/datalake/NS11071K/users/yongyub/DD_BGC/LIM_CS/skill/Cyclostationary_LIM_MATLABstyle_CSWhite_PP_forecast_skill_23month_3month_running_mean_leave7yearblockout_5yearinit_corr_threshold05_RECCAP2_all_regions_valid_zero30.nc
# <xarray.Dataset> Size: 2MB
# Dimensions:                               (region: 21, init_time: 336,
#                                            lead: 23, init_month: 12,
#                                            validation_fold: 4, month: 12,
#                                            fit_lag: 7, state_to: 11,
#                                            state_from: 11)
# Coordinates:
#   * region                                (region) int16 42B 1 2 3 ... 27 28 29
#   * init_time                             (init_time) datetime64[ns] 3kB 1998...
#   * lead                                  (lead) int16 46B 1 2 3 4 ... 21 22 23
#   * init_month                            (init_month) int16 24B 1 2 3 ... 11 12
#   * validation_fold                       (validation_fold) int16 8B 0 1 2 3
#   * month                                 (month) int16 24B 1 2 3 4 ... 10 11 12
#   * fit_lag                               (fit_lag) int16 14B 0 1 2 3 4 5 6
#   * state_to                              (state_to) object 88B 'PP' ... 'SASD'
#   * state_from                            (state_from) object 88B 'PP' ... 'S...
# Data variables: (12/22)
#     PP_prediction                         (region, init_time, lead) float32 649kB ...
#     PP_correlation_skill                  (region, lead) float32 2kB 0.4741 ....
#     PP_correlation_skill_by_init_month    (region, init_month, lead) float32 23kB ...
#     PP_correlation_skill_by_fold          (region, validation_fold, lead) float32 8kB ...
#     n_pairs                               (region, lead) int16 966B 240 ... 240
#     n_pairs_by_init_month                 (region, init_month, lead) int16 12kB ...
#     ...                                    ...
#     fold_end_year                         (validation_fold) int16 8B 2004 ......
#     fold_n_years                          (validation_fold) int16 8B 7 7 7 7
#     fold_n_months                         (validation_fold) int16 8B 84 84 84 84
#     region_name                           (region) object 168B 'NA SPSS' ... ...
#     basin                                 (region) object 168B 'atlantic' ......
#     original_region_id                    (region) int16 42B 1 2 3 4 ... 3 1 2 3
# Attributes: (12/25)
#     title:                               Stable CS-White blocked OOS centered...
#     state_vector_source_file:            /nird/datalake/NS11071K/users/yongyu...
#     cross_validation:                    Four consecutive non-overlapping lea...
#     strict_within_validation_block:      True
#     training_covariance_rule:            For K(t,lag), every month from t thr...
#     verification_rule:                   All leads use the same 60 initializa...
#     ...                                  ...
#     A_fourier_modes:                     2
#     covariance_ridge:                    0.0
#     pinv_rcond:                          1e-10
#     min_phase_samples:                   12
#     important_note:                      The original monthly state vector is...
#     date_created:                        2026-07-21

# %%
# ============================================================
# 4. Heatmap and regional lines from OOS skill
# ============================================================

with xr.open_dataset(CV_SKILL_FILE) as ds:
    ds_skill = ds.load()

r_pool = ds_skill["PP_correlation_skill"]
n_pool = ds_skill["n_pairs"]
r_fold = ds_skill["PP_correlation_skill_by_fold"]
n_fold_pairs = ds_skill["n_pairs_by_fold"]
leads = r_pool.lead.values.astype(np.int16)

# Fold labels from the saved validation periods.
fold_values = r_fold.validation_fold.values
fold_labels = []
for ifold in fold_values:
    if "fold_start_year" in ds_skill and "fold_end_year" in ds_skill:
        y0 = int(ds_skill["fold_start_year"].sel(validation_fold=ifold).values)
        y1 = int(ds_skill["fold_end_year"].sel(validation_fold=ifold).values)
        fold_labels.append(f"Fold {int(ifold) + 1}: {y0}–{y1}")
    else:
        fold_labels.append(f"Fold {int(ifold) + 1}")

keep_regions = [
    int(reg) for reg in r_pool.region.values
    if int(reg) not in EXCLUDE_REGIONS
]
region_basin = {int(reg): get_basin_name(ds_skill, reg) for reg in keep_regions}
basin_rank = {name: i for i, name in enumerate(BASIN_ORDER)}
regions_plot = np.array(
    sorted(
        keep_regions,
        key=lambda reg: (basin_rank.get(region_basin[reg], len(BASIN_ORDER)), reg),
    ),
    dtype=np.int16,
)

r_pool = r_pool.sel(region=regions_plot)
n_pool = n_pool.sel(region=regions_plot)
r_fold = r_fold.sel(region=regions_plot)
n_fold_pairs = n_fold_pairs.sel(region=regions_plot)
n_region_plot = len(regions_plot)

basin_groups = []
for basin_name in BASIN_ORDER:
    idx = [
        i for i, reg in enumerate(regions_plot)
        if region_basin[int(reg)] == basin_name
    ]
    if idx:
        basin_groups.append({"name": basin_name, "start": min(idx), "end": max(idx)})

basin_centers = [0.5 * (g["start"] + g["end"] + 1) for g in basin_groups]
basin_labels = [BASIN_SHORT.get(g["name"], g["name"]) for g in basin_groups]

fig, ax = plt.subplots(figsize=(14.5, 0.48 * n_region_plot + 3.8))
y_edges = np.arange(n_region_plot + 1)
x_edges = np.arange(leads[0] - 0.5, leads[-1] + 1.5, 1.0)

im = ax.pcolormesh(
    x_edges,
    y_edges,
    r_pool.values,
    vmin=-1,
    vmax=1,
    cmap="RdBu_r",
    shading="auto",
)

for ireg in range(n_region_plot):
    for ilead, lead in enumerate(leads):
        if np.isfinite(r_pool.values[ireg, ilead]) and r_pool.values[ireg, ilead] >= THRESHOLD:
            ax.plot(lead, ireg + 0.5, "k.", markersize=3)

for group in basin_groups[:-1]:
    ax.axhline(group["end"] + 1, color="k", lw=1.8)

ax_basin = ax.twinx()
ax_basin.set_ylim(0, n_region_plot)
ax_basin.set_yticks(basin_centers)
ax_basin.set_yticklabels(basin_labels, fontsize=11, fontweight="bold")
ax_basin.tick_params(axis="y", length=0, pad=4)
for spine in ax_basin.spines.values():
    spine.set_visible(False)

if leads[-1] >= 12:
    ax.axvline(12, color="k", lw=0.8, alpha=0.4)
ax.set_xlim(leads[0] - 0.5, leads[-1] + 0.5)
ax.set_ylim(0, n_region_plot)
ax.set_xlabel("Forecast lead month")
ax.set_ylabel("RECCAP2 valid-zero30 region")
ax.set_title(
    "MATLAB-style CS-White LIM PP out-of-sample forecast skill, pooled held-out starts\n"
    "Leave-7-year-block-out, first 5 years initialized; centered 3-month running mean; "
    f"black dots: r ≥ {THRESHOLD}",
    fontsize=14,
)
ax.set_xticks(np.arange(leads[0], leads[-1] + 1, 2))
ax.set_yticks(np.arange(n_region_plot) + 0.5)
ax.set_yticklabels(
    [get_region_label(ds_skill, reg, short=True) for reg in regions_plot],
    fontsize=9,
)

fig.subplots_adjust(left=0.20, right=0.83, top=0.90, bottom=0.10)
cax = fig.add_axes([0.875, 0.16, 0.018, 0.68])
cbar = fig.colorbar(im, cax=cax)
cbar.set_label("Out-of-sample correlation\n(centered 3-month mean)")

if SAVE_FIGURES:
    fig.savefig(FIG_HEATMAP, dpi=200, bbox_inches="tight")
plt.show()

ncol = 4
nrow = int(np.ceil(n_region_plot / ncol))
fig, axes = plt.subplots(
    nrow,
    ncol,
    figsize=(16, 3.0 * nrow),
    sharex=True,
    sharey=True,
)
axes = np.asarray(axes).ravel()

for iax, (ax, reg) in enumerate(zip(axes, regions_plot)):
    r = r_pool.sel(region=reg)
    n = n_pool.sel(region=reg)
    rf = r_fold.sel(region=reg)
    nf = n_fold_pairs.sel(region=reg)

    finite_n = n.values[np.isfinite(n.values)]
    n_text = (
        f"pooled n={int(np.nanmin(finite_n))}–{int(np.nanmax(finite_n))}"
        if finite_n.size else "pooled n=NA"
    )

    # Individual validation-fold skill.
    for j, ifold in enumerate(fold_values):
        r_this = rf.sel(validation_fold=ifold)
        n_this = nf.sel(validation_fold=ifold)
        finite_nf = n_this.values[np.isfinite(n_this.values)]
        fold_n_text = (
            f", n={int(np.nanmin(finite_nf))}–{int(np.nanmax(finite_nf))}"
            if finite_nf.size else ""
        )

        ax.plot(
            leads,
            r_this.values,
            lw=1.0,
            alpha=0.70,
            label=fold_labels[j] + fold_n_text,
        )

    # Pooled correlation from all held-out starts.
    # This is not the arithmetic mean of the four fold correlations.
    ax.plot(
        leads,
        r.values,
        color="k",
        marker="o",
        lw=2.4,
        ms=3.5,
        label="Pooled OOS",
        zorder=10,
    )

    ax.axhline(THRESHOLD, color="k", lw=1.0, ls="--", alpha=0.7)
    ax.axhline(0, color="k", lw=0.6, alpha=0.4)
    ax.set_title(
        f"{region_basin[int(reg)]}\n"
        f"{get_region_label(ds_skill, reg, short=True)}, {n_text}",
        fontsize=8.5,
    )
    ax.set_xlim(leads[0], leads[-1])
    ax.set_ylim(-1, 1)
    ax.grid(alpha=0.25)

for ax in axes[n_region_plot:]:
    ax.axis("off")
for i, ax in enumerate(axes[:n_region_plot]):
    ax.set_xlabel("Lead month")
    if i % ncol == 0:
        ax.set_ylabel("Correlation")

# One shared legend: fold lines plus thick black pooled skill.
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(
    handles,
    labels,
    loc="upper center",
    bbox_to_anchor=(0.5, 1.035),
    ncol=min(len(labels), 5),
    frameon=False,
    fontsize=9,
)

fig.suptitle(
    "CS-White LIM PP out-of-sample skill by region\n"
    "Thin lines: individual 7-year validation folds; thick black: pooled held-out starts",
    fontsize=15,
    y=1.075,
)
plt.tight_layout(rect=[0, 0, 1, 0.96])
if SAVE_FIGURES:
    fig.savefig(FIG_LINES, dpi=200, bbox_inches="tight")
plt.show()

# %%
# ============================================================
# 5. Map of latest OOS skillful lead
# ============================================================

import cartopy.crs as ccrs
import cartopy.feature as cfeature

if not VALID_MASK_FILE.exists():
    raise FileNotFoundError(f"Mask file not found:\n{VALID_MASK_FILE}")

with xr.open_dataset(VALID_MASK_FILE) as ds:
    ds_mask = ds.load()
with xr.open_dataset(CV_SKILL_FILE) as ds:
    ds_map_skill = ds.load()

mask = ds_mask["valid_region_mask"]
latest = ds_map_skill["latest_lead_corr_ge_05"]
lat = ds_mask.latitude.values.astype(float)
lon = ds_mask.longitude.values.astype(float)
mask_values = mask.values.astype(np.int16)

mask_plot_full = mask_values.copy()
for reg_ex in EXCLUDE_REGIONS:
    mask_plot_full[mask_plot_full == reg_ex] = 0

mask_region_set = set(np.unique(mask_plot_full[mask_plot_full > 0]).astype(int))
regions_to_plot = [
    int(reg) for reg in latest.region.values
    if int(reg) not in EXCLUDE_REGIONS and int(reg) in mask_region_set
]
latest_plot = latest.sel(region=regions_to_plot)

lead_map = np.full(mask_values.shape, np.nan, dtype=np.float32)
for reg in latest_plot.region.values:
    reg = int(reg)
    lead_map[mask_plot_full == reg] = float(latest_plot.sel(region=reg).values)
lead_map = np.where(mask_plot_full > 0, lead_map, np.nan)

lat_plot = lat[::PLOT_STRIDE]
lon_plot = lon[::PLOT_STRIDE]
lead_plot = lead_map[::PLOT_STRIDE, ::PLOT_STRIDE]
mask_plot = mask_plot_full[::PLOT_STRIDE, ::PLOT_STRIDE].astype(float)
lead_cyc, lon_cyc = add_cyclic_manual(lead_plot, lon_plot)
mask_cyc, _ = add_cyclic_manual(mask_plot, lon_plot)

remaining_regions = np.unique(mask_plot_full[mask_plot_full > 0])
boundary_levels = np.arange(0.5, int(np.nanmax(remaining_regions)) + 1.5, 1.0)

lead_cyc_plot = np.where(
    np.isfinite(lead_cyc),
    np.minimum(lead_cyc, DISPLAY_MAX_LEAD),
    np.nan,
)
bounds = np.arange(-0.5, DISPLAY_MAX_LEAD + 1.5, 1.0)
try:
    base = plt.get_cmap("turbo", DISPLAY_MAX_LEAD)
except ValueError:
    base = plt.get_cmap("plasma", DISPLAY_MAX_LEAD)
colors = [(0.82, 0.82, 0.82, 1.0)] + [base(i) for i in range(DISPLAY_MAX_LEAD)]
cmap = ListedColormap(colors)
cmap.set_bad((1, 1, 1, 0))
norm = BoundaryNorm(bounds, cmap.N)

fig = plt.figure(figsize=(13.5, 6.2))
ax = plt.axes(projection=ccrs.Robinson(central_longitude=CENTRAL_LONGITUDE))
im = ax.pcolormesh(
    lon_cyc,
    lat_plot,
    lead_cyc_plot,
    cmap=cmap,
    norm=norm,
    shading="auto",
    transform=ccrs.PlateCarree(),
)
ax.contour(
    lon_cyc,
    lat_plot,
    mask_cyc,
    levels=boundary_levels,
    colors="k",
    linewidths=0.30,
    transform=ccrs.PlateCarree(),
)
ax.add_feature(cfeature.LAND, facecolor="0.92", edgecolor="none", zorder=3)
ax.coastlines(linewidth=0.45, zorder=4)
ax.set_global()
ax.set_title(
    "Latest PP forecast lead with out-of-sample correlation ≥ 0.5\n"
    "MATLAB-style CS-White LIM, leave-7-year-block-out, first 5 years initialized, centered 3-month mean\n"
    "valid-zero30 RECCAP mask (excluding R6, R18, R19, R29)",
    fontsize=12.5,
)

for reg in latest_plot.region.values:
    reg = int(reg)
    region_mask = mask_plot_full == reg
    if not np.any(region_mask):
        continue
    lon_c, lat_c = weighted_centroid(lon, lat, region_mask)
    if not (np.isfinite(lon_c) and np.isfinite(lat_c)):
        continue
    value = int(latest_plot.sel(region=reg).values)
    ax.text(
        lon_to_180(lon_c),
        lat_c,
        f"R{reg}\n{value}M",
        transform=ccrs.PlateCarree(),
        ha="center",
        va="center",
        fontsize=7.2,
        fontweight="bold",
        linespacing=0.85,
        bbox=dict(facecolor="white", edgecolor="none", alpha=0.78, boxstyle="round,pad=0.14"),
        zorder=5,
    )

fig.subplots_adjust(left=0.03, right=0.97, top=0.84, bottom=0.16)
cax = fig.add_axes([0.20, 0.08, 0.60, 0.035])
cbar = fig.colorbar(
    im,
    cax=cax,
    orientation="horizontal",
    ticks=np.arange(0, DISPLAY_MAX_LEAD + 1, 1),
    boundaries=bounds,
)
cbar.set_label("Latest OOS lead with centered 3-month-mean r ≥ 0.5")
cbar.ax.text(
    0,
    -1.8,
    "0 = no skillful lead",
    ha="center",
    va="top",
    transform=cbar.ax.get_xaxis_transform(),
    fontsize=8,
)
cbar.ax.text(
    DISPLAY_MAX_LEAD,
    -1.8,
    f"{DISPLAY_MAX_LEAD} = {DISPLAY_MAX_LEAD} months or longer",
    ha="center",
    va="top",
    transform=cbar.ax.get_xaxis_transform(),
    fontsize=8,
)

if SAVE_FIGURES:
    fig.savefig(MAP_FIG, dpi=200, bbox_inches="tight")
plt.show()
