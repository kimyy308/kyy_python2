# %% [markdown]
# # Module and DASK setting

# %%
# DASK client set

import os
import sys
from dask.distributed import Client
# client = Client(scheduler_file='/proj/kimyy/Dropbox/source/python/all/mpi/scheduler.json', threads_per_worker=2, n_workers=6)
client = Client(scheduler_file='/proj/kimyy/Dropbox/source/python/all/mpi/scheduler.json')
# client = Client(scheduler_file='/proj/kimyy/Dropbox/source/python/all/mpi/scheduler_10.json')  

def setup_module_path():
    module_path = '/proj/kimyy/Dropbox/source/python/all/Modules/CESM2'
    if module_path not in sys.path:
        sys.path.append(module_path)

client.run(setup_module_path)

client

# get path for path changes in Jupyter notebook: File - Open from Path - insert relative_path
notebook_path = os.path.abspath(".")
_, _, relative_path = notebook_path.partition('/all/')
relative_path = '/all/' + relative_path
relative_path
# Out:
# '/all/Model/CESM2/Earth_System_Predictability/ASSM/Aleph'

# %%
# load public modules

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as patches
import matplotlib.ticker as mticker
import matplotlib.path as mpath
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from scipy import stats
from scipy.interpolate import griddata
import cmocean
from cmcrameri import cm
import warnings
warnings.simplefilter(action='ignore')
import pandas as pd
import cftime
import pop_tools
from pprint import pprint
import time
import subprocess
import re as re_mod
import cftime
import datetime
from scipy.stats import ttest_1samp
import xcesm
# from scipy.stats import pearsonr
from scipy.stats import t

# %%
# load private modules

import sys
sys.path.append('/proj/kimyy/Dropbox/source/python/all/Modules/CESM2')
from KYY_CESM2_preprocessing import CESM2_config

savefilepath = "/mnt/lustre/proj/kimyy/tmp_python/HCST_skills_HCST-LE"

# %%
cfg_var_SST=CESM2_config()
cfg_var_SST.year_s=1960
cfg_var_SST.year_e=2020
cfg_var_SST.setvar('SST')

start_date = cftime.DatetimeNoLeap(cfg_var_SST.year_s, 2, 1)
end_date = cftime.DatetimeNoLeap(cfg_var_SST.year_e+1, 1, 1)

ds_grid = pop_tools.get_grid('POP_gx1v7')

# %%
def process_coords_bgc_surface(
    ds, sd, ed, varname, drop=True,
    except_coord_vars=["time","lon","lat","TLONG","TLAT","SST", "SSH","NO3","photoC_TOT_zint_100m", "TREFHT", "PSL", "PRECT", "TWS", "GPP", "FAREA_BURNED"]
):
    import xcesm
    import numpy as np
    import datetime

    coord_vars = []
    for v in np.array(ds.coords):
        if v not in except_coord_vars:
            coord_vars.append(v)
    for v in np.array(ds.data_vars):
        if v not in except_coord_vars:
            coord_vars.append(v)

    if drop:
        ds = ds.drop(coord_vars)
        ds = ds.sel(time=slice(sd, ed))
        ds = ds.isel(z_t=0) 
        ds_rgd = ds[varname].utils.regrid()

        new_time = ds_rgd.time - np.array([datetime.timedelta(days=15)] * len(ds.time))
        ds_rgd = ds_rgd.assign_coords(time=new_time)
        ds['lat'] = ds['lat'].round(4)
        ds['lon'] = ds['lon'].round(4)
        return ds_rgd
    else:
        return ds.set_coords(coord_vars)


def process_coords_2d(
    ds, sd, ed, varname, drop=True,
    except_coord_vars=["time","lon","lat","TLONG","TLAT","SST", "SSH","NO3","photoC_TOT_zint_100m", "TREFHT", "PSL", "PRECT", "TWS", "GPP", "FAREA_BURNED"]

):
    import xcesm
    import numpy as np
    import datetime

    coord_vars = []
    for v in np.array(ds.coords):
        if v not in except_coord_vars:
            coord_vars.append(v)
    for v in np.array(ds.data_vars):
        if v not in except_coord_vars:
            coord_vars.append(v)

    if drop:
        ds = ds.drop(coord_vars)
        ds = ds.sel(time=slice(sd, ed))
        # ds_rgd = ds[varname].utils.regrid()
        # new_time = ds_rgd.time - np.array([datetime.timedelta(days=15)] * len(ds.time))
        # ds_rgd = ds_rgd.assign_coords(time=new_time)
        new_time = ds.time - np.array([datetime.timedelta(days=15)] * len(ds.time))
        ds = ds.assign_coords(time=new_time)      
        ds=ds.groupby('time.year').mean(dim='time', skipna=True)
        ds['lat'] = ds['lat'].round(4)
        ds['lon'] = ds['lon'].round(4)
        return ds
    else:
        return ds.set_coords(coord_vars)



def process_coords_bgc_surface_hcst(
    ds, sd, ed, varname, drop=True,
    except_coord_vars=["time","lon","lat","TLONG","TLAT","SST", "SSH","NO3","photoC_TOT_zint_100m", "TREFHT", "PSL", "PRECT", "TWS", "GPP", "FAREA_BURNED"]
):
    import xcesm
    import numpy as np
    import datetime

    coord_vars = []
    for v in np.array(ds.coords):
        if v not in except_coord_vars:
            coord_vars.append(v)
    for v in np.array(ds.data_vars):
        if v not in except_coord_vars:
            coord_vars.append(v)

    if drop:
        ds = ds.drop(coord_vars)
        # ds = ds.isel(z_t_150m=slice(0,10)) 
        ds = ds.isel(z_t_150m=0) 
        ds_rgd = ds[varname].utils.regrid()

        new_time = ds_rgd.time - np.array([datetime.timedelta(days=15)] * len(ds.time))
        ds_rgd = ds_rgd.assign_coords(time=new_time)
        ds['lat'] = ds['lat'].round(4)
        ds['lon'] = ds['lon'].round(4)
        return ds_rgd
    else:
        return ds.set_coords(coord_vars)


def process_coords_2d_hcst(
    ds, sd, ed, varname, drop=True,
    except_coord_vars=["time","lon","lat","TLONG","TLAT","SST", "SSH","NO3","photoC_TOT_zint_100m", "TREFHT", "PSL", "PRECT", "TWS", "GPP", "FAREA_BURNED"]
):
    import xcesm
    import numpy as np
    import datetime

    coord_vars = []
    for v in np.array(ds.coords):
        if v not in except_coord_vars:
            coord_vars.append(v)
    for v in np.array(ds.data_vars):
        if v not in except_coord_vars:
            coord_vars.append(v)

    if drop:
        ds = ds.drop(coord_vars)
        # ds_rgd = ds[varname].utils.regrid()
        # new_time = ds_rgd.time - np.array([datetime.timedelta(days=15)] * len(ds.time))
        # ds_rgd = ds_rgd.assign_coords(time=new_time)
        new_time = ds.time - np.array([datetime.timedelta(days=15)] * len(ds.time))
        ds = ds.assign_coords(time=new_time)
        ds=ds.groupby('time.year').mean(dim='time', skipna=True)
        ds['lat'] = ds['lat'].round(4)
        ds['lon'] = ds['lon'].round(4)
        return ds
    else:
        return ds.set_coords(coord_vars)

# %%
# Read LE dataset (SST)

start_time = time.time()

cfg_var_SST.LE_path_load(cfg_var_SST.var)

fpath_SST = savefilepath + "/LE_SST_output*.nc"


cfg_var_SST.LE_ds = []
for imem in range(0, len(cfg_var_SST.LE_file_list[0])):
    SST_LE_ds_tmp = xr.open_mfdataset(cfg_var_SST.LE_file_list[0][imem], 
                           chunks={'time': 5}, 
                           combine='nested',
                           parallel=True,
                           preprocess=lambda ds: process_coords_2d(ds, start_date, end_date, 'SST'),
                           decode_cf=True, 
                           decode_times=True)
    
    SST_LE_ds_tmp = SST_LE_ds_tmp.expand_dims({'ens_LE': 1})
    cfg_var_SST.LE_ds.append(SST_LE_ds_tmp)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print('elasped time for reading LE, ' + str(imem) + ': ' + str(elapsed_time))

cfg_var_SST.LE_ds = xr.concat(cfg_var_SST.LE_ds, dim='ens_LE')
cfg_var_SST.LE_ds['ens_LE']=range(0, len(cfg_var_SST.LE_file_list[0]))
cfg_var_SST.LE_ds=cfg_var_SST.LE_ds.compute()
# Out:
# elasped time for reading LE, 0: 12.47792363166809
# elasped time for reading LE, 1: 16.664344787597656
# elasped time for reading LE, 2: 20.938654899597168
# elasped time for reading LE, 3: 25.055885314941406
# elasped time for reading LE, 4: 29.2139310836792
# elasped time for reading LE, 5: 33.66727638244629
# elasped time for reading LE, 6: 37.89186668395996
# elasped time for reading LE, 7: 42.085633277893066
# elasped time for reading LE, 8: 46.397172689437866
# elasped time for reading LE, 9: 50.30598306655884
# elasped time for reading LE, 10: 53.992342472076416
# elasped time for reading LE, 11: 58.35973238945007
# elasped time for reading LE, 12: 62.42756485939026
# elasped time for reading LE, 13: 66.776846408844
# elasped time for reading LE, 14: 70.94828081130981
# elasped time for reading LE, 15: 75.18238687515259
# elasped time for reading LE, 16: 79.21568846702576
# elasped time for reading LE, 17: 83.41791105270386
# elasped time for reading LE, 18: 87.42975163459778
# elasped time for reading LE, 19: 93.99092197418213
# elasped time for reading LE, 20: 98.05414891242981
# elasped time for reading LE, 21: 102.20864987373352
# elasped time for reading LE, 22: 106.90542244911194
# elasped time for reading LE, 23: 111.0728178024292
# elasped time for reading LE, 24: 115.21308898925781
# elasped time for reading LE, 25: 119.77419257164001
# elasped time for reading LE, 26: 124.0185604095459
# elasped time for reading LE, 27: 131.32677030563354
# elasped time for reading LE, 28: 135.53889417648315
# elasped time for reading LE, 29: 139.73258209228516
# elasped time for reading LE, 30: 143.89887380599976
# elasped time for reading LE, 31: 148.134215593338
# elasped time for reading LE, 32: 152.47318530082703
# elasped time for reading LE, 33: 156.7155089378357
# elasped time for reading LE, 34: 160.74298238754272
# elasped time for reading LE, 35: 164.9509916305542
# elasped time for reading LE, 36: 169.3676872253418
# elasped time for reading LE, 37: 173.89208507537842
# elasped time for reading LE, 38: 178.1373016834259
# elasped time for reading LE, 39: 182.40283966064453
# elasped time for reading LE, 40: 186.66573095321655
# elasped time for reading LE, 41: 190.8143491744995
# elasped time for reading LE, 42: 195.8361473083496
# elasped time for reading LE, 43: 199.93002796173096
# elasped time for reading LE, 44: 204.11796951293945
# elasped time for reading LE, 45: 208.61677193641663
# elasped time for reading LE, 46: 212.96762084960938
# elasped time for reading LE, 47: 217.10148692131042
# elasped time for reading LE, 48: 221.27014136314392
# elasped time for reading LE, 49: 225.64982962608337

# %%
# HCST SST

cfg_var_SST.HCST_ds = []
HCST_ds_xr = []

start_time = time.time()

cfg_var_SST.HCST_path_load(cfg_var_SST.var)

for iyear in range(0, len(cfg_var_SST.HCST_file_list)):
    SST_HCST_ds_tmp = xr.open_mfdataset(cfg_var_SST.HCST_file_list[iyear], 
                           chunks={'time': 4}, 
                           combine='nested',
                           concat_dim=[[*cfg_var_SST.HCST_ensembles], 'year'], 
                           parallel=True,
                           preprocess=lambda ds: process_coords_2d_hcst(ds, start_date, end_date, 'SST'),
                           decode_cf=True, 
                           decode_times=True)
    
    SST_HCST_ds_tmp = SST_HCST_ds_tmp.rename({"year": "lyears"})
    SST_HCST_ds_tmp['lyears']=range(1,6)
    SST_HCST_ds_tmp = SST_HCST_ds_tmp.expand_dims({'iyear': 1})
    
    cfg_var_SST.HCST_ds.append(SST_HCST_ds_tmp)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print('elasped time for reading HCST SST, ' + str(iyear) + ': ' + str(elapsed_time))

cfg_var_SST.HCST_ds = xr.concat(cfg_var_SST.HCST_ds, dim='iyear')
cfg_var_SST.HCST_ds = cfg_var_SST.HCST_ds.rename({"concat_dim": "ens_HCST"})
cfg_var_SST.HCST_ds['ens_HCST']=range(0, len(cfg_var_SST.HCST_file_list[0]))
cfg_var_SST.HCST_ds['iyear']=range(cfg_var_SST.year_s, cfg_var_SST.year_e+1)
cfg_var_SST.HCST_ds=cfg_var_SST.HCST_ds.compute()
# Out:
# elasped time for reading HCST SST, 0: 17.715754508972168
# elasped time for reading HCST SST, 1: 18.281638622283936
# elasped time for reading HCST SST, 2: 18.826735734939575
# elasped time for reading HCST SST, 3: 19.376030683517456
# elasped time for reading HCST SST, 4: 19.901851654052734
# elasped time for reading HCST SST, 5: 20.7691650390625
# elasped time for reading HCST SST, 6: 21.305104970932007
# elasped time for reading HCST SST, 7: 21.868179082870483
# elasped time for reading HCST SST, 8: 22.414310455322266
# elasped time for reading HCST SST, 9: 22.967474460601807
# elasped time for reading HCST SST, 10: 23.517557859420776
# elasped time for reading HCST SST, 11: 24.03641629219055
# elasped time for reading HCST SST, 12: 24.579558849334717
# elasped time for reading HCST SST, 13: 25.112762212753296
# elasped time for reading HCST SST, 14: 25.648260831832886
# elasped time for reading HCST SST, 15: 26.2024564743042
# elasped time for reading HCST SST, 16: 26.747222900390625
# elasped time for reading HCST SST, 17: 27.27335834503174
# elasped time for reading HCST SST, 18: 27.83904790878296
# elasped time for reading HCST SST, 19: 28.412041425704956
# elasped time for reading HCST SST, 20: 32.59466075897217
# elasped time for reading HCST SST, 21: 33.14629578590393
# elasped time for reading HCST SST, 22: 33.70581936836243
# elasped time for reading HCST SST, 23: 34.26371192932129
# elasped time for reading HCST SST, 24: 34.79959726333618
# elasped time for reading HCST SST, 25: 35.35900568962097
# elasped time for reading HCST SST, 26: 36.19749903678894
# elasped time for reading HCST SST, 27: 36.76172757148743
# elasped time for reading HCST SST, 28: 37.64040684700012
# elasped time for reading HCST SST, 29: 38.17198300361633
# elasped time for reading HCST SST, 30: 38.733327865600586
# elasped time for reading HCST SST, 31: 39.27539396286011
# elasped time for reading HCST SST, 32: 39.81438088417053
# elasped time for reading HCST SST, 33: 40.3484628200531
# elasped time for reading HCST SST, 34: 41.246403217315674
# elasped time for reading HCST SST, 35: 41.780641078948975
# elasped time for reading HCST SST, 36: 42.3385009765625
# elasped time for reading HCST SST, 37: 42.90217113494873
# elasped time for reading HCST SST, 38: 43.44727563858032
# elasped time for reading HCST SST, 39: 43.986144065856934
# elasped time for reading HCST SST, 40: 44.55567264556885
# elasped time for reading HCST SST, 41: 45.101577281951904
# elasped time for reading HCST SST, 42: 45.643107414245605
# elasped time for reading HCST SST, 43: 46.17579197883606
# elasped time for reading HCST SST, 44: 46.71717119216919
# elasped time for reading HCST SST, 45: 47.27945566177368
# elasped time for reading HCST SST, 46: 47.83613348007202
# elasped time for reading HCST SST, 47: 48.72091460227966
# elasped time for reading HCST SST, 48: 49.243064403533936
# elasped time for reading HCST SST, 49: 49.78049921989441
# elasped time for reading HCST SST, 50: 50.30981779098511
# elasped time for reading HCST SST, 51: 50.682616233825684
# elasped time for reading HCST SST, 52: 51.01655626296997
# elasped time for reading HCST SST, 53: 51.35134029388428
# elasped time for reading HCST SST, 54: 51.681662797927856
# elasped time for reading HCST SST, 55: 52.217236280441284
# elasped time for reading HCST SST, 56: 52.999547481536865
# elasped time for reading HCST SST, 57: 53.56811785697937
# elasped time for reading HCST SST, 58: 54.427162885665894
# elasped time for reading HCST SST, 59: 54.950446367263794
# elasped time for reading HCST SST, 60: 55.49778890609741

# %%
cfg_var_SST.HCST_ds_yearly = cfg_var_SST.HCST_ds.sel(iyear=slice("1960-01-01", "2020-12-31")).isel(lyears=0).rename({"iyear": "year"})

# %%
# get rolling mean variables (SST)

cfg_var_SST.LE_ds_4yr = cfg_var_SST.LE_ds.rolling(year=4, min_periods=4).mean()
obs_rolling_time_mean = cfg_var_SST.LE_ds['year'].rolling(year=4, min_periods=4).mean()
cfg_var_SST.LE_ds_4yr = cfg_var_SST.LE_ds_4yr.assign_coords(year=obs_rolling_time_mean)
valid_index = np.where(~np.isnan(cfg_var_SST.LE_ds_4yr['year']))[0]
cfg_var_SST.LE_ds_4yr = cfg_var_SST.LE_ds_4yr.isel(year=valid_index)
cfg_var_SST.LE_ds_4yr = cfg_var_SST.LE_ds_4yr.isel(year=range(1,58))

# hcst_da_ly25=cfg_var_SST.HCST_ds.sel(iyear=slice("1996-01-01", "2016-12-31"), lyears=slice(2, 5))
hcst_da_ly25=cfg_var_SST.HCST_ds.sel(iyear=slice("1959", "2016"), lyears=slice(2, 5))
cfg_var_SST.HCST_ds_4yr=hcst_da_ly25.mean(dim='lyears')
cfg_var_SST.HCST_ds_4yr=cfg_var_SST.HCST_ds_4yr.rename(iyear="year")
cfg_var_SST.HCST_ds_4yr['year']=cfg_var_SST.LE_ds_4yr['year']

# %%
# get skills
start_time = time.time()


corr_SST_LE_HCST = xr.corr(cfg_var_SST.LE_ds['SST'], cfg_var_SST.HCST_ds_yearly['SST'], dim='year').compute()
# corr_SST_LE_HCST_obs_period = xr.corr(cfg_var_SST.LE_ds, cfg_var_SST.HCST_ds_yearly, dim='year')
# em
# em-obs_period

end_time = time.time()
elapsed_time = end_time - start_time
print('elasped time for reading HCST SST, ' + str(iyear) + ': ' + str(elapsed_time))
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-40846' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40837' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40829' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40823' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40819' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40812' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40807' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[110], line 5
#       1 # get skills
#       2 start_time = time.time()
# ----> 5 corr_SST_LE_HCST = xr.corr(cfg_var_SST.LE_ds['SST'], cfg_var_SST.HCST_ds_yearly['SST'], dim='year').compute()
#       6 # corr_SST_LE_HCST_obs_period = xr.corr(cfg_var_SST.LE_ds, cfg_var_SST.HCST_ds_yearly, dim='year')
#       7 # em
#       9 end_time = time.time()
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/core/dataarray.py:1206, in DataArray.compute(self, **kwargs)
#    1181 """Manually trigger loading of this array's data from disk or a
#    1182 remote source into memory and return a new array.
#    1183
#    (...)
#    1203 dask.compute
#    1204 """
#    1205 new = self.copy(deep=False)
# -> 1206 return new.load(**kwargs)
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/core/dataarray.py:1174, in DataArray.load(self, **kwargs)
#    1154 def load(self, **kwargs) -> Self:
#    1155     """Manually trigger loading of this array's data from disk or a
#    1156     remote source into memory and return this array.
#    1157
#    (...)
#    1172     dask.compute
#    1173     """
# -> 1174     ds = self._to_temp_dataset().load(**kwargs)
#    1175     new = self._from_temp_dataset(ds)
#    1176     self._variable = new._variable
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/core/dataset.py:900, in Dataset.load(self, **kwargs)
#     897 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     899 # evaluate all the chunked arrays simultaneously
# --> 900 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     901     *lazy_data.values(), **kwargs
#     902 )
#     904 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     905     self.variables[k].data = data
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/dask/base.py:666, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     663     keys.append(x.__dask_keys__())
#     664     postcomputes.append(x.__dask_postcompute__())
# --> 666 results = schedule(dsk, keys, **kwargs)
#     667 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:3259, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3257         should_rejoin = False
#    3258 try:
# -> 3259     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3260 finally:
#    3261     for f in futures.values():
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2384, in Client.gather(self, futures, errors, direct, asynchronous)
#    2382 except ValueError:
#    2383     local_worker = None
# -> 2384 return self.sync(
#    2385     self._gather,
#    2386     futures,
#    2387     errors=errors,
#    2388     direct=direct,
#    2389     local_worker=local_worker,
#    2390     asynchronous=asynchronous,
#    2391 )
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/utils.py:359, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     357     return future
#     358 else:
# --> 359     return sync(
#     360         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     361     )
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/utils.py:422, in sync(loop, func, callback_timeout, *args, **kwargs)
#     420 else:
#     421     while not e.is_set():
# --> 422         wait(10)
#     424 if error:
#     425     typ, exc, tb = error
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/utils.py:411, in sync.<locals>.wait(timeout)
#     409 def wait(timeout):
#     410     try:
# --> 411         return e.wait(timeout)
#     412     except KeyboardInterrupt:
#     413         loop.add_callback(cancel)
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Task exception was never retrieved
# future: <Task finished name='Task-40801' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40798' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40792' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40783' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40777' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40772' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40759' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40753' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40746' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40735' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40729' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40724' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40717' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40712' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40707' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40701' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40693' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40685' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40679' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40675' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40669' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40664' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40654' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40649' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40643' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40632' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40627' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40621' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40614' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40609' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40602' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40598' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40590' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40581' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40577' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40571' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40567' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40555' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40549' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40546' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40541' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40537' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40532' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40526' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40520' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40513' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40499' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40493' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40489' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40482' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40476' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40473' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40468' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40460' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40450' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40446' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40433' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40428' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40423' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40884' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40873' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40867' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40860' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40855' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40851' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40840' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40834' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40828' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40818' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40814' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40802' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40799' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40793' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40787' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40775' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40766' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40760' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40750' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40744' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40734' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40728' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40722' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# ...
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41118' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41111' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41103' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41096' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41091' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41082' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41076' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41070' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41062' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41056' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41048' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41032' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41024' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41020' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-41012' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40997' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40991' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40986' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40981' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40969' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40955' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40949' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40942' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40937' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40922' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40902' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40897' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40890' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40885' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40877' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40871' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40865' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-40859' coro=<Client._gather.<locals>.wait() done, defined at /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py:2212> exception=AllExit()>
# Traceback (most recent call last):
#   File "/mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/distributed/client.py", line 2221, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
 # save temporary file (HCST)
corr_SST_LE_HCST.to_netcdf(savefilepath + "/HCST_SST_corr" + ".nc")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[109], line 2
#       1 # save temporary file (HCST)
# ----> 2 corr_SST_LE_HCST.to_netcdf(savefilepath + "/HCST_SST_corr" + ".nc")
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/core/dataarray.py:4204, in DataArray.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf, auto_complex)
#    4200 else:
#    4201     # No problems with the name - so we're fine!
#    4202     dataset = self.to_dataset()
# -> 4204 return to_netcdf(  # type: ignore[return-value]  # mypy cannot resolve the overloads:(
#    4205     dataset,
#    4206     path,
#    4207     mode=mode,
#    4208     format=format,
#    4209     group=group,
#    4210     engine=engine,
#    4211     encoding=encoding,
#    4212     unlimited_dims=unlimited_dims,
#    4213     compute=compute,
#    4214     multifile=False,
#    4215     invalid_netcdf=invalid_netcdf,
#    4216     auto_complex=auto_complex,
#    4217 )
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/backends/api.py:1937, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf, auto_complex)
#    1934 if multifile:
#    1935     return writer, store
# -> 1937 writes = writer.sync(compute=compute)
#    1939 if isinstance(target, BytesIO):
#    1940     store.sync()
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/backends/common.py:358, in ArrayWriter.sync(self, compute, chunkmanager_store_kwargs)
#     355 if chunkmanager_store_kwargs is None:
#     356     chunkmanager_store_kwargs = {}
# --> 358 delayed_store = chunkmanager.store(
#     359     self.sources,
#     360     self.targets,
#     361     lock=self.lock,
#     362     compute=compute,
#     363     flush=True,
#     364     regions=self.regions,
#     365     **chunkmanager_store_kwargs,
#     366 )
#     367 self.sources = []
#     368 self.targets = []
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:247, in DaskManager.store(self, sources, targets, **kwargs)
#     239 def store(
#     240     self,
#     241     sources: Any | Sequence[Any],
#     242     targets: Any,
#     243     **kwargs: Any,
#     244 ) -> Any:
#     245     from dask.array import store
# --> 247     return store(
#     248         sources=sources,
#     249         targets=targets,
#     250         **kwargs,
#     251     )
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:81, in __setitem__()
#      79 def __setitem__(self, key, value):
#      80     with self.datastore.lock:
# ---> 81         data = self.get_array(needs_lock=False)
#      82         data[key] = value
#      83         if self.datastore.autoclose:
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:94, in get_array()
#      93 def get_array(self, needs_lock=True):
# ---> 94     ds = self.datastore._acquire(needs_lock)
#      95     variable = ds.variables[self.variable_name]
#      96     variable.set_auto_maskandscale(False)
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:455, in _acquire()
#     454 def _acquire(self, needs_lock=True):
# --> 455     with self._manager.acquire_context(needs_lock) as root:
#     456         ds = _nc4_require_group(root, self._group, self._mode)
#     457     return ds
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/contextlib.py:137, in __enter__()
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/backends/file_manager.py:199, in acquire_context()
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /mnt/lustre/proj/kimyy/APP/conda/miniconda3/envs/kdask/lib/python3.11/site-packages/xarray/backends/file_manager.py:217, in _acquire_with_cache_info()
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2353, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:1963, in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -101] NetCDF: HDF error: b'/mnt/lustre/proj/kimyy/tmp_python/HCST_skills_HCST-LE/HCST_SST_corr.nc'

# %%
# critical r with alpha=0.1, alpha=0.34
N = 19
alpha = 0.34  # two-sided, so alpha/2 = 0.05
df = N - 2

# 1) Find t_crit for a two-sided test at alpha=0.1
t_crit = t.ppf(1 - alpha/2, df)  # e.g., ppf(0.95) for the upper 5% tail

# 2) Solve for the correlation threshold
rho_crit = np.sqrt(t_crit**2 / ((N - 2) + t_crit**2))
print(f"N={N}, alpha={alpha}, df={df}")
print(f"t_crit = {t_crit:.3f}")
print(f"Correlation threshold ≈ ±{rho_crit:.3f}")
# Out:
# N=19, alpha=0.34, df=17
# t_crit = 0.982
# Correlation threshold ≈ ±0.232
