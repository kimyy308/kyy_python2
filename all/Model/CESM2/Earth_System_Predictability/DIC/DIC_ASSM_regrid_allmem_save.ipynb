# %%
# DASK client set

import os
import sys
from dask.distributed import Client
# client = Client(scheduler_file='/proj/kimyy/Dropbox/source/python/all/mpi/scheduler.json', threads_per_worker=2, n_workers=6)
client = Client(scheduler_file='/proj/kimyy/Dropbox/source/python/all/mpi/scheduler.json')
# client = Client(scheduler_file='/proj/kimyy/Dropbox/source/python/all/mpi/scheduler_10.json')  

# add private module path for workers
# client.run(lambda: os.environ.update({'PYTHONPATH': '/proj/kimyy/Dropbox/source/python/all/Modules/CESM2'}))
# def add_path():
#     if '/proj/kimyy/Dropbox/source/python/all/Modules/CESM2' not in sys.path:
#         sys.path.append('/proj/kimyy/Dropbox/source/python/all/Modules/CESM2')

# client.run(add_path)

def setup_module_path():
    module_path = '/proj/kimyy/Dropbox/source/python/all/Modules/CESM2'
    if module_path not in sys.path:
        sys.path.append(module_path)

client.run(setup_module_path)

client

# get path for path changes in Jupyter notebook: File - Open from Path - insert relative_path
notebook_path = os.path.abspath(".")
_, _, relative_path = notebook_path.partition('/all/')
relative_path = '/all/' + relative_path
relative_path
# Out:
# '/all/Model/CESM2/Earth_System_Predictability/DIC'

# %% [markdown]
# # Load modules

# %%
# load public modules

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as patches
import matplotlib.ticker as mticker
import matplotlib.path as mpath
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from scipy import stats
from scipy.interpolate import griddata
import cmocean
from cmcrameri import cm
import warnings
warnings.simplefilter(action='ignore')
import pandas as pd
import cftime
import pop_tools
from pprint import pprint
import time
import subprocess
import re as re_mod
import cftime
import datetime
from scipy.stats import ttest_1samp

# %%
import xcesm
import gsw

# %%
# load private modules

import sys
sys.path.append('/proj/kimyy/Dropbox/source/python/all/Modules/CESM2')
from KYY_CESM2_NWP_preprocessing import CESM2_NWP_config
# import KYY_CESM2_preprocessing
# import importlib
# importlib.reload(KYY_CESM2_preprocessing)

# %% [markdown]
# # Variable configuration

# %%
cfgs = {}
# varlist = ["DIC", "TEMP", "SALT"]
# varlist = ["DIC_ALT_CO2"]
# varlist = ["FG_CO2"]
varlist = ["DIC", "TEMP", "SALT", "DIC_ALT_CO2"]
for varname in varlist:
    cfg = CESM2_NWP_config()
    cfg.year_s = 1955
    cfg.year_e = 2020
    cfg.setvar(varname)
    cfgs[varname] = cfg

if cfgs[varname].comp=='ocn':
    ds_grid = pop_tools.get_grid('POP_gx1v7')

# %% [markdown]
# # Read dataset

# %%
# lat_range = slice(23, 38)
# lon_range = slice(120, 180)
lat_range = slice(19, 40)
lon_range = slice(120, 180)

# %%
# define preprocessing function

# exceptcv=['time','lon','lat','lev', 'TAREA', 'TLONG', 'TLAT', 'z_t', 'z_t_2', cfg_var_DIC.var, cfg_var_TEMP.var]
# exceptcv=['time','lon','lat','lev', 'TAREA', 'TLONG', 'TLAT', 'z_t', 'dz', 'z_t_2', cfg_var_DIC.var, cfg_var_TEMP.var]


# exceptcv = [
#     'time', 'lon', 'lat', 'lev', 'TAREA', 'TLONG', 'TLAT', 'z_w', 'z_w_top', 'z_t', 'ULONG', 'ULAT', 'VLONG', 'VLAT'
# ] + [cfg.var for cfg in cfgs.values()]
exceptcv = [
    'time', 'lon', 'lat', 'lev', 'TAREA', 'TLONG', 'TLAT', 'z_t', 
] + [cfg.var for cfg in cfgs.values()]


def process_coords_3d(ds, sd, ed, drop=True, except_coord_vars=exceptcv):
    """Preprocessor function to drop all non-dim coords, which slows down concatenation."""
    coord_vars = []
    for v in np.array(ds.coords) :
        if not v in except_coord_vars:
            coord_vars += [v]
    for v in np.array(ds.data_vars) :
        if not v in except_coord_vars:
            coord_vars += [v]

    if drop:
        ds= ds.drop(coord_vars)
        ds= ds.sel(time=slice(sd, ed))
        # ds = ds.isel(z_t=slice(0, 39)) # ~39 layer (1000m)
        # ds = (ds.isel(z_t=slice(1, 39)) * ds.dz).sum(dim='z_t') / ds.dz.sum(dim='z_t')
        return ds
    else:
        return ds.set_coords(coord_vars)



def process_coords_3d_LE(ds, sd, ed, drop=True, except_coord_vars=exceptcv):
    """
    Preprocessor function for CESM POP-style datasets.
    - Normalizes vertical coordinate: if z_t or z_t_2 exists, rename to 'depth'.
    - Replaces its values with z_t_new for consistency.
    - Optionally drops unnecessary coordinate variables for faster concatenation.
    """
    z_t_new = np.array([5.0000000e+00, 1.5000000e+01, 2.5000000e+01, 3.5000000e+01,
       4.5000000e+01, 5.5000000e+01, 6.5000000e+01, 7.5000000e+01,
       8.5000000e+01, 9.5000000e+01, 1.0500000e+02, 1.1500000e+02,
       1.2500000e+02, 1.3500000e+02, 1.4500000e+02, 1.5500000e+02,
       1.6509839e+02, 1.7547903e+02, 1.8629126e+02, 1.9766026e+02,
       2.0971138e+02, 2.2257828e+02, 2.3640883e+02, 2.5137015e+02,
       2.6765421e+02, 2.8548364e+02, 3.0511920e+02, 3.2686798e+02,
       3.5109348e+02, 3.7822760e+02, 4.0878464e+02, 4.4337769e+02,
       4.8273669e+02, 5.2772797e+02, 5.7937286e+02, 6.3886261e+02,
       7.0756329e+02, 7.8700250e+02, 8.7882520e+02, 9.8470581e+02,
       1.1062042e+03, 1.2445669e+03, 1.4004972e+03, 1.5739464e+03,
       1.7640033e+03, 1.9689442e+03, 2.1864565e+03, 2.4139714e+03,
       2.6490012e+03, 2.8893845e+03, 3.1334045e+03, 3.3797935e+03,
       3.6276702e+03, 3.8764519e+03, 4.1257681e+03, 4.3753926e+03,
       4.6251904e+03, 4.8750835e+03, 5.1250278e+03, 5.3750000e+03])
    
    # ------------------------------------------------------
    # 1️⃣ Normalize vertical coordinate name
    # ------------------------------------------------------
    if "z_t_2" in ds.dims:
        ds = ds.rename({"z_t_2": "depth"})
    elif "z_t" in ds.dims:
        ds = ds.rename({"z_t": "depth"})
    else:
        print("[Warning] No vertical coordinate (z_t or z_t_2) found — skipped.")
        return ds

    # Drop any leftover z_t/z_t_2 coordinate variable if it exists
    ds = ds.drop_vars(["z_t", "z_t_2"], errors="ignore")

    # ------------------------------------------------------
    # 2️⃣ Replace coordinate values with z_t_new
    # ------------------------------------------------------
    if "depth" in ds.coords:
        if len(ds["depth"]) == len(z_t_new):
            ds = ds.assign_coords(depth=z_t_new)
        else:
            print(f"[Warning] depth length mismatch: {len(ds['depth'])} vs {len(z_t_new)}")
    else:
        print("[Warning] depth coordinate missing after renaming.")

    # ------------------------------------------------------
    # 3️⃣ Clean up coordinate references inside variable attributes
    # ------------------------------------------------------
    for v in ds.data_vars:
        if "coordinates" in ds[v].attrs:
            ds[v].attrs["coordinates"] = (
                ds[v].attrs["coordinates"]
                .replace("z_t_2", "depth")
                .replace("z_t", "depth")
            )

    # ------------------------------------------------------
    # 4️⃣ Drop unnecessary coordinate variables and slice time
    # ------------------------------------------------------
    coord_vars = []
    for v in np.array(ds.coords):
        if v not in except_coord_vars:
            coord_vars.append(v)
    for v in np.array(ds.data_vars):
        if v not in except_coord_vars:
            coord_vars.append(v)

    if drop:
        ds = ds.drop(coord_vars, errors="ignore")
        ds = ds.sel(time=slice(sd, ed))
    else:
        ds = ds.set_coords(coord_vars)

    return ds



# exceptcv=['time','lon','lat','lev', 'TLONG', 'TLAT', 'z_t', cfg_var_DIC.var, cfg_var_Li_diat.var, cfg_var_Li_sp.var,
#          cfg_var_Vi_diat_Fe.var, cfg_var_Vi_diat_N.var, cfg_var_Vi_diat_P.var, cfg_var_Vi_diat_SiO3.var,
#          cfg_var_Vi_sp_Fe.var, cfg_var_Vi_sp_N.var, cfg_var_Vi_sp_P.var,
#          cfg_var_NPP_diat.var, cfg_var_NPP_sp.var]
# def process_coords(ds, sd, ed, drop=True, except_coord_vars=exceptcv):
#     """Preprocessor function to drop all non-dim coords, which slows down concatenation."""
#     coord_vars = []
#     for v in np.array(ds.coords) :
#         if not v in except_coord_vars:
#             coord_vars += [v]
#     for v in np.array(ds.data_vars) :
#         if not v in except_coord_vars:
#             coord_vars += [v]
    
#     if drop:
#         ds= ds.drop(coord_vars)
#         ds= ds.sel(time=slice(sd, ed))
#         return ds
#     else:
#         return ds.set_coords(coord_vars)

start_date = cftime.DatetimeNoLeap(cfgs[varname].year_s, 2, 1)
end_date = cftime.DatetimeNoLeap(cfgs[varname].year_e+1, 1, 1)


# ds = ds.isel(lev=slice(1, 11))

# %%
# vars = varlist
# results = {}

# for var in vars:
#     print(f"\n===== Processing {var} =====")

#     cfg_var = cfgs[var]
#     cfg_var.var = var

#     # ================= ODA =================
#     t0 = time.time()
#     cfg_var.ODA_path_load(cfg_var.var)
#     cfg_var.ODA_ds = xr.open_mfdataset(
#         cfg_var.ODA_file_list[0][15:16],
#         chunks={'time': 12},
#         combine='nested',
#         concat_dim=[[*cfg_var.ODA_ensembles][15:16], 'time'],
#         parallel=True,
#         preprocess=lambda ds: process_coords_3d(ds, start_date, end_date),
#         decode_cf=True,
#         decode_times=True,
#     )
#     cfg_var.ODA_ds = cfg_var.ODA_ds.rename({"concat_dim": "ens_ODA"})
#     new_time = cfg_var.ODA_ds.time - np.array(
#         [datetime.timedelta(days=15)] * len(cfg_var.ODA_ds.time)
#     )
#     cfg_var.ODA_ds = cfg_var.ODA_ds.assign_coords(time=new_time)
#     print(f"  ODA read: {time.time() - t0:.1f} s")

    

#     # ================= REGRID =================
#     t0 = time.time()

#     cfg_var.ODA_ds_rgd = (
#         cfg_var.ODA_ds[var]
#         .isel(ens_ODA=0)
#         .utils.regrid()
#         .sel(lat=lat_range, lon=lon_range)
#         .sortby("time")
#     )
#     print(f"  REGRID ODA: {time.time() - t0:.1f} s")
   
#     # cfg_var.LE_ds_rgd = cfg_var.LE_ds_rgd.assign_coords(
#     #     z_t=cfg_var.ODA_ds_rgd.z_t
#     # )
    

#     results[var] = cfg_var

# %%
import xarray as xr
import numpy as np
import datetime
import time
import os

OUT_BASE = "/mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA"

vars = varlist
results = {}

for var in vars:
    print(f"\n===== Processing {var} =====")

    cfg_var = cfgs[var]
    cfg_var.var = var

    # Load ODA file paths
    cfg_var.ODA_path_load(var)

    for ens_idx, ens_name in enumerate(cfg_var.ODA_ensembles):
        print(f"\n--- ODA ensemble {ens_name} ---")

        file_list = cfg_var.ODA_file_list[0][ens_idx]

        for i, in_file in enumerate(file_list):
            print(f"[{ens_name}] {i+1}/{len(file_list)}")
            print(f"INPUT : {in_file}")

            t0 = time.time()

            # Open single file
            ds = xr.open_dataset(
                in_file,
                chunks={"time": 12},
                decode_cf=True,
                decode_times=True,
            )

            ds = process_coords_3d(
                ds, start_date, end_date
            )

            # Time shift
            new_time = ds.time - np.array(
                [datetime.timedelta(days=15)] * len(ds.time)
            )
            ds = ds.assign_coords(time=new_time)

            # Regrid
            da_rgd = (
                ds[var]
                .utils.regrid()
                .sel(lat=lat_range, lon=lon_range)
                .sortby("time")
            )

            # Extract ensemble short name
            parts = in_file.split("/")
            filename = os.path.basename(in_file)

            ens_short = None
            for p in parts:
                if "assm." in p:
                    ens_short = p.split("assm.")[-1]
                    break

            if ens_short is None:
                raise ValueError("Could not detect ODA ensemble name")

            # Build output path
            new_dir = os.path.join(
                OUT_BASE,
                "NWP",
                "ocn",
                var,
                ens_short,
            )
            os.makedirs(new_dir, exist_ok=True)

            new_filename = f"regridded_{filename}"
            out_file = os.path.join(new_dir, new_filename)

            # Save
            encoding = {
                var: {
                    "zlib": True,
                    "complevel": 4,
                    "dtype": "float32",
                }
            }

            da_rgd.to_netcdf(out_file, encoding=encoding)

            ds.close()
            del ds, da_rgd

            print(f"OUTPUT: {out_file}")
            print(f"Saved in {time.time() - t0:.1f} s\n")

    results[var] = cfg_var
# Out:
# ===== Processing FG_CO2 =====
#
# --- ODA ensemble 0 ---
# [0] 1/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.195101-195512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.195101-195512.nc
# Saved in 0.2 s
#
# [0] 2/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.195601-196012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.195601-196012.nc
# Saved in 0.2 s
#
# [0] 3/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.196101-196512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.196101-196512.nc
# Saved in 0.2 s
#
# [0] 4/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.196601-197012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.196601-197012.nc
# Saved in 0.3 s
#
# [0] 5/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.197101-197512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.197101-197512.nc
# Saved in 0.2 s
#
# [0] 6/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.197601-198012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.197601-198012.nc
# Saved in 0.2 s
#
# [0] 7/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.198101-198512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.198101-198512.nc
# Saved in 0.2 s
#
# [0] 8/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.198601-199012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.198601-199012.nc
# Saved in 0.2 s
#
# [0] 9/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.199101-199512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.199101-199512.nc
# Saved in 0.2 s
#
# [0] 10/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.199601-200012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.199601-200012.nc
# Saved in 0.3 s
#
# [0] 11/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.200101-200512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.200101-200512.nc
# Saved in 0.2 s
#
# [0] 12/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.200601-201012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.200601-201012.nc
# Saved in 0.3 s
#
# [0] 13/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.201101-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.201101-201412.nc
# Saved in 0.2 s
#
# [0] 14/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.2 s
#
# [0] 15/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.202001-202112.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p1/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p1.pop.h.FG_CO2.202001-202112.nc
# Saved in 0.2 s
#
#
# --- ODA ensemble 1 ---
# [1] 1/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.195101-195512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.195101-195512.nc
# Saved in 0.2 s
#
# [1] 2/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.195601-196012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.195601-196012.nc
# Saved in 0.2 s
#
# [1] 3/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.196101-196512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.196101-196512.nc
# Saved in 0.2 s
#
# [1] 4/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.196601-197012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.196601-197012.nc
# Saved in 0.2 s
#
# [1] 5/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.197101-197512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.197101-197512.nc
# Saved in 0.2 s
#
# [1] 6/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.197601-198012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.197601-198012.nc
# Saved in 0.2 s
#
# [1] 7/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.198101-198512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.198101-198512.nc
# Saved in 0.2 s
#
# [1] 8/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.198601-199012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.198601-199012.nc
# Saved in 0.2 s
#
# [1] 9/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.199101-199512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.199101-199512.nc
# Saved in 0.2 s
#
# [1] 10/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.199601-200012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.199601-200012.nc
# Saved in 0.2 s
#
# [1] 11/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.200101-200512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.200101-200512.nc
# Saved in 0.3 s
#
# [1] 12/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.200601-201012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.200601-201012.nc
# Saved in 0.2 s
#
# [1] 13/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.201101-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.201101-201412.nc
# Saved in 0.2 s
#
# [1] 14/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.3 s
#
# [1] 15/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p2/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.202001-202112.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p2/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p2.pop.h.FG_CO2.202001-202112.nc
# Saved in 0.2 s
#
#
# --- ODA ensemble 2 ---
# [2] 1/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.195101-195512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.195101-195512.nc
# Saved in 0.2 s
#
# [2] 2/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.195601-196012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.195601-196012.nc
# Saved in 0.3 s
#
# [2] 3/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.196101-196512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.196101-196512.nc
# Saved in 0.2 s
#
# [2] 4/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.196601-197012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.196601-197012.nc
# Saved in 0.2 s
#
# [2] 5/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.197101-197512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.197101-197512.nc
# Saved in 0.2 s
#
# [2] 6/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.197601-198012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.197601-198012.nc
# Saved in 0.3 s
#
# [2] 7/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.198101-198512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.198101-198512.nc
# Saved in 0.3 s
#
# [2] 8/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.198601-199012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.198601-199012.nc
# Saved in 0.3 s
#
# [2] 9/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.199101-199512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.199101-199512.nc
# Saved in 0.2 s
#
# [2] 10/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.199601-200012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.199601-200012.nc
# Saved in 0.3 s
#
# [2] 11/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.200101-200512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.200101-200512.nc
# Saved in 0.3 s
#
# [2] 12/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.200601-201012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.200601-201012.nc
# Saved in 0.2 s
#
# [2] 13/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.201101-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.201101-201412.nc
# Saved in 0.2 s
#
# [2] 14/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.2 s
#
# [2] 15/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p3/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.202001-202112.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p3/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p3.pop.h.FG_CO2.202001-202112.nc
# Saved in 0.2 s
#
#
# --- ODA ensemble 3 ---
# [3] 1/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.195101-195512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.195101-195512.nc
# Saved in 0.2 s
#
# [3] 2/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.195601-196012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.195601-196012.nc
# Saved in 0.3 s
#
# [3] 3/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.196101-196512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.196101-196512.nc
# Saved in 0.3 s
#
# [3] 4/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.196601-197012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.196601-197012.nc
# Saved in 0.3 s
#
# [3] 5/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.197101-197512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.197101-197512.nc
# Saved in 0.2 s
#
# [3] 6/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.197601-198012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.197601-198012.nc
# Saved in 0.2 s
#
# [3] 7/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.198101-198512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.198101-198512.nc
# Saved in 0.3 s
#
# [3] 8/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.198601-199012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.198601-199012.nc
# Saved in 0.6 s
#
# [3] 9/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.199101-199512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.199101-199512.nc
# Saved in 0.3 s
#
# [3] 10/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.199601-200012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.199601-200012.nc
# Saved in 0.3 s
#
# [3] 11/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.200101-200512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.200101-200512.nc
# Saved in 0.3 s
#
# [3] 12/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.200601-201012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.200601-201012.nc
# Saved in 0.3 s
#
# [3] 13/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.201101-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.201101-201412.nc
# Saved in 0.2 s
#
# [3] 14/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.3 s
#
# [3] 15/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p4/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.202001-202112.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p4/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p4.pop.h.FG_CO2.202001-202112.nc
# Saved in 0.2 s
#
#
# --- ODA ensemble 4 ---
# [4] 1/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.195101-195512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.195101-195512.nc
# Saved in 0.2 s
#
# [4] 2/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.195601-196012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.195601-196012.nc
# Saved in 0.2 s
#
# [4] 3/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.196101-196512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.196101-196512.nc
# Saved in 0.3 s
#
# [4] 4/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.196601-197012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.196601-197012.nc
# Saved in 0.3 s
#
# [4] 5/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.197101-197512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.197101-197512.nc
# Saved in 0.4 s
#
# [4] 6/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.197601-198012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.197601-198012.nc
# Saved in 0.3 s
#
# [4] 7/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.198101-198512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.198101-198512.nc
# Saved in 0.3 s
#
# [4] 8/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.198601-199012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.198601-199012.nc
# Saved in 0.3 s
#
# [4] 9/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.199101-199512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.199101-199512.nc
# Saved in 0.3 s
#
# [4] 10/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.199601-200012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.199601-200012.nc
# Saved in 0.3 s
#
# [4] 11/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.200101-200512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.200101-200512.nc
# Saved in 0.2 s
#
# [4] 12/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.200601-201012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.200601-201012.nc
# Saved in 0.3 s
#
# [4] 13/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.201101-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.201101-201412.nc
# Saved in 0.2 s
#
# [4] 14/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.2 s
#
# [4] 15/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p5/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.202001-202112.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-10p5/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-10p5.pop.h.FG_CO2.202001-202112.nc
# Saved in 0.2 s
#
#
# --- ODA ensemble 5 ---
# [5] 1/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.195101-195512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.195101-195512.nc
# Saved in 0.2 s
#
# [5] 2/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.195601-196012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.195601-196012.nc
# Saved in 0.3 s
#
# [5] 3/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.196101-196512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.196101-196512.nc
# Saved in 0.3 s
#
# [5] 4/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.196601-197012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.196601-197012.nc
# Saved in 0.3 s
#
# [5] 5/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.197101-197512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.197101-197512.nc
# Saved in 0.3 s
#
# [5] 6/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.197601-198012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.197601-198012.nc
# Saved in 0.3 s
#
# [5] 7/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.198101-198512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.198101-198512.nc
# Saved in 0.3 s
#
# [5] 8/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.198601-199012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.198601-199012.nc
# Saved in 0.3 s
#
# [5] 9/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.199101-199512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.199101-199512.nc
# Saved in 0.3 s
#
# [5] 10/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.199601-200012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.199601-200012.nc
# Saved in 0.3 s
#
# [5] 11/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.200101-200512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.200101-200512.nc
# Saved in 0.3 s
#
# [5] 12/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.200601-201012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.200601-201012.nc
# Saved in 0.3 s
#
# [5] 13/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.201101-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.201101-201412.nc
# Saved in 0.3 s
#
# [5] 14/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.2 s
#
# [5] 15/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.202001-202112.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p1/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p1.pop.h.FG_CO2.202001-202112.nc
# Saved in 0.2 s
#
#
# --- ODA ensemble 6 ---
# [6] 1/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.195101-195512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.195101-195512.nc
# Saved in 0.2 s
#
# [6] 2/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.195601-196012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.195601-196012.nc
# Saved in 0.2 s
#
# [6] 3/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.196101-196512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.196101-196512.nc
# Saved in 0.3 s
#
# [6] 4/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.196601-197012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.196601-197012.nc
# Saved in 0.3 s
#
# [6] 5/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.197101-197512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.197101-197512.nc
# Saved in 0.3 s
#
# [6] 6/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.197601-198012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.197601-198012.nc
# Saved in 0.2 s
#
# [6] 7/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.198101-198512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.198101-198512.nc
# Saved in 0.3 s
#
# [6] 8/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.198601-199012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.198601-199012.nc
# Saved in 0.3 s
#
# [6] 9/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.199101-199512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.199101-199512.nc
# Saved in 0.2 s
#
# [6] 10/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.199601-200012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.199601-200012.nc
# Saved in 0.3 s
#
# [6] 11/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.200101-200512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.200101-200512.nc
# Saved in 0.3 s
#
# [6] 12/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.200601-201012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.200601-201012.nc
# Saved in 0.3 s
#
# [6] 13/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.201101-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.201101-201412.nc
# Saved in 0.2 s
#
# [6] 14/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.2 s
#
# [6] 15/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p2/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.202001-202112.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p2/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p2.pop.h.FG_CO2.202001-202112.nc
# Saved in 0.2 s
#
#
# --- ODA ensemble 7 ---
# [7] 1/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.195101-195512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.195101-195512.nc
# Saved in 0.2 s
#
# [7] 2/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.195601-196012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.195601-196012.nc
# Saved in 0.3 s
#
# [7] 3/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.196101-196512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.196101-196512.nc
# Saved in 0.3 s
#
# [7] 4/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.196601-197012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.196601-197012.nc
# Saved in 0.3 s
#
# [7] 5/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.197101-197512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.197101-197512.nc
# Saved in 0.3 s
#
# [7] 6/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.197601-198012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.197601-198012.nc
# Saved in 0.3 s
#
# [7] 7/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.198101-198512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.198101-198512.nc
# Saved in 0.3 s
#
# [7] 8/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.198601-199012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.198601-199012.nc
# Saved in 0.2 s
#
# [7] 9/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.199101-199512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.199101-199512.nc
# Saved in 0.2 s
#
# [7] 10/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.199601-200012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.199601-200012.nc
# Saved in 0.3 s
#
# [7] 11/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.200101-200512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.200101-200512.nc
# Saved in 0.3 s
#
# [7] 12/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.200601-201012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.200601-201012.nc
# Saved in 0.2 s
#
# [7] 13/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.201101-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.201101-201412.nc
# Saved in 0.3 s
#
# [7] 14/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.2 s
#
# [7] 15/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p3/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.202001-202112.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p3/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.en4.2_ba-20p3.pop.h.FG_CO2.202001-202112.nc
# Saved in 0.2 s
#
#
# --- ODA ensemble 8 ---
# [8] 1/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p4.pop.h.FG_CO2.195101-195512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p4.pop.h.FG_CO2.195101-195512.nc
# Saved in 0.2 s
#
# [8] 2/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p4.pop.h.FG_CO2.195601-196012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p4.pop.h.FG_CO2.195601-196012.nc
# Saved in 0.2 s
#
# [8] 3/15
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p4.pop.h.FG_CO2.196101-196512.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/en4.2_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.en4.2_ba-20p4.pop.h.FG_CO2.196101-196512.nc
# Saved in 0.3 s
#
# [8] 4/15
# ...
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.2020-11.nc
# Saved in 0.1 s
#
# [18] 12/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.2020-12.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.2020-12.nc
# Saved in 0.1 s
#
# [18] 13/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.195501-195912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.195501-195912.nc
# Saved in 0.3 s
#
# [18] 14/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.196001-196412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.196001-196412.nc
# Saved in 0.2 s
#
# [18] 15/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.196501-196912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.196501-196912.nc
# Saved in 0.3 s
#
# [18] 16/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.197001-197412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.197001-197412.nc
# Saved in 0.3 s
#
# [18] 17/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.197501-197912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.197501-197912.nc
# Saved in 0.3 s
#
# [18] 18/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.198001-198412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.198001-198412.nc
# Saved in 0.2 s
#
# [18] 19/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.198501-198912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.198501-198912.nc
# Saved in 0.3 s
#
# [18] 20/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.199001-199412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.199001-199412.nc
# Saved in 0.2 s
#
# [18] 21/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.199501-199912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.199501-199912.nc
# Saved in 0.3 s
#
# [18] 22/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.200001-200412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.200001-200412.nc
# Saved in 0.3 s
#
# [18] 23/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.200501-200912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.200501-200912.nc
# Saved in 0.2 s
#
# [18] 24/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.201001-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.201001-201412.nc
# Saved in 0.3 s
#
# [18] 25/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p4/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p4/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p4.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.2 s
#
#
# --- ODA ensemble 19 ---
# [19] 1/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-01.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-01.nc
# Saved in 0.1 s
#
# [19] 2/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-02.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-02.nc
# Saved in 0.2 s
#
# [19] 3/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-03.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-03.nc
# Saved in 0.1 s
#
# [19] 4/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-04.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-04.nc
# Saved in 0.2 s
#
# [19] 5/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-05.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-05.nc
# Saved in 0.1 s
#
# [19] 6/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-06.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-06.nc
# Saved in 0.1 s
#
# [19] 7/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-07.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-07.nc
# Saved in 0.2 s
#
# [19] 8/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-08.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-08.nc
# Saved in 0.3 s
#
# [19] 9/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-09.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-09.nc
# Saved in 0.1 s
#
# [19] 10/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-10.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-10.nc
# Saved in 0.1 s
#
# [19] 11/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-11.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-11.nc
# Saved in 0.1 s
#
# [19] 12/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-12.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_FG_CO2_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.2020-12.nc
# Saved in 0.1 s
#
# [19] 13/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.195501-195912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.195501-195912.nc
# Saved in 0.3 s
#
# [19] 14/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.196001-196412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.196001-196412.nc
# Saved in 0.2 s
#
# [19] 15/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.196501-196912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.196501-196912.nc
# Saved in 0.3 s
#
# [19] 16/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.197001-197412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.197001-197412.nc
# Saved in 0.3 s
#
# [19] 17/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.197501-197912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.197501-197912.nc
# Saved in 0.3 s
#
# [19] 18/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.198001-198412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.198001-198412.nc
# Saved in 0.2 s
#
# [19] 19/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.198501-198912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.198501-198912.nc
# Saved in 0.3 s
#
# [19] 20/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.199001-199412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.199001-199412.nc
# Saved in 0.2 s
#
# [19] 21/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.199501-199912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.199501-199912.nc
# Saved in 0.3 s
#
# [19] 22/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.200001-200412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.200001-200412.nc
# Saved in 0.3 s
#
# [19] 23/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.200501-200912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.200501-200912.nc
# Saved in 0.3 s
#
# [19] 24/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.201001-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.201001-201412.nc
# Saved in 0.3 s
#
# [19] 25/25
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ASSM_EXP/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/ODA/NWP/ocn/FG_CO2/projdv7.3_ba-20p5/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p5.pop.h.FG_CO2.201501-201912.nc
# Saved in 0.3 s

# %%
import xarray as xr
import numpy as np
import datetime
import time
import os

OUT_BASE = "/mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA"

vars = varlist
results = {}

for var in vars:
    print(f"\n===== Processing {var} (WDA) =====")

    cfg_var = cfgs[var]
    cfg_var.var = var

    # Load WDA file paths
    cfg_var.WDA_path_load(var)

    # ------------------------------------------------------------
    # WDA file_list structure (ODA style, but no ensemble)
    # IMPORTANT: WDA_file_list is nested -> use [0][0]
    # ------------------------------------------------------------
    file_list = cfg_var.WDA_file_list[0][0]

    for i, in_file in enumerate(file_list):
        print(f"[WDA] {i+1}/{len(file_list)}")
        print(f"INPUT : {in_file}")

        t0 = time.time()

        # Open single file (UNCHANGED)
        ds = xr.open_dataset(
            in_file,
            chunks={"time": 12},
            decode_cf=True,
            decode_times=True,
        )

        ds = process_coords_3d(ds, start_date, end_date)

        # Time shift (UNCHANGED)
        new_time = ds.time - np.array(
            [datetime.timedelta(days=15)] * len(ds.time)
        )
        ds = ds.assign_coords(time=new_time)

        # Regrid (UNCHANGED)
        da_rgd = (
            ds[var]
            .utils.regrid()
            .sel(lat=lat_range, lon=lon_range)
            .sortby("time")
        )

        # Output dir (no ensemble folder)
        filename = os.path.basename(in_file)

        new_dir = os.path.join(
            OUT_BASE,
            "NWP",
            "ocn",
            var,
        )
        os.makedirs(new_dir, exist_ok=True)

        new_filename = f"regridded_{filename}"
        out_file = os.path.join(new_dir, new_filename)

        # Save (UNCHANGED)
        encoding = {
            var: {
                "zlib": True,
                "complevel": 4,
                "dtype": "float32",
            }
        }

        da_rgd.to_netcdf(out_file, encoding=encoding)

        ds.close()
        del ds, da_rgd

        print(f"OUTPUT: {out_file}")
        print(f"Saved in {time.time() - t0:.1f} s\n")

    results[var] = cfg_var
# Out:
# ===== Processing DIC (WDA) =====
# [WDA] 1/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.195501-195912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.195501-195912.nc
# Saved in 7.1 s
#
# [WDA] 2/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.196001-196412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.196001-196412.nc
# Saved in 7.3 s
#
# [WDA] 3/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.196501-196912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.196501-196912.nc
# Saved in 7.0 s
#
# [WDA] 4/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.197001-197412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.197001-197412.nc
# Saved in 6.9 s
#
# [WDA] 5/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.197501-197912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.197501-197912.nc
# Saved in 7.4 s
#
# [WDA] 6/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.198001-198412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.198001-198412.nc
# Saved in 7.3 s
#
# [WDA] 7/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.198501-198912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.198501-198912.nc
# Saved in 7.4 s
#
# [WDA] 8/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.199001-199412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.199001-199412.nc
# Saved in 6.8 s
#
# [WDA] 9/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.199501-199912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.199501-199912.nc
# Saved in 7.1 s
#
# [WDA] 10/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.200001-200412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.200001-200412.nc
# Saved in 7.4 s
#
# [WDA] 11/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.200501-200912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.200501-200912.nc
# Saved in 7.4 s
#
# [WDA] 12/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.201001-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.201001-201412.nc
# Saved in 6.9 s
#
# [WDA] 13/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.201501-201912.nc
# Saved in 6.8 s
#
# [WDA] 14/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.202001-202012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC.202001-202012.nc
# Saved in 1.6 s
#
#
# ===== Processing TEMP (WDA) =====
# [WDA] 1/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.195501-195912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.195501-195912.nc
# Saved in 6.6 s
#
# [WDA] 2/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.196001-196412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.196001-196412.nc
# Saved in 8.0 s
#
# [WDA] 3/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.196501-196912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.196501-196912.nc
# Saved in 6.8 s
#
# [WDA] 4/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.197001-197412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.197001-197412.nc
# Saved in 6.9 s
#
# [WDA] 5/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.197501-197912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.197501-197912.nc
# Saved in 5.2 s
#
# [WDA] 6/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.198001-198412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.198001-198412.nc
# Saved in 6.8 s
#
# [WDA] 7/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.198501-198912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.198501-198912.nc
# Saved in 6.9 s
#
# [WDA] 8/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.199001-199412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.199001-199412.nc
# Saved in 7.1 s
#
# [WDA] 9/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.199501-199912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.199501-199912.nc
# Saved in 6.9 s
#
# [WDA] 10/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.200001-200412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.200001-200412.nc
# Saved in 7.3 s
#
# [WDA] 11/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.200501-200912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.200501-200912.nc
# Saved in 6.8 s
#
# [WDA] 12/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.201001-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.201001-201412.nc
# Saved in 7.0 s
#
# [WDA] 13/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.201501-201912.nc
# Saved in 7.5 s
#
# [WDA] 14/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.202001-202012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/TEMP/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.TEMP.202001-202012.nc
# Saved in 2.0 s
#
#
# ===== Processing SALT (WDA) =====
# [WDA] 1/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.195501-195912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.195501-195912.nc
# Saved in 6.7 s
#
# [WDA] 2/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.196001-196412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.196001-196412.nc
# Saved in 6.6 s
#
# [WDA] 3/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.196501-196912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.196501-196912.nc
# Saved in 7.0 s
#
# [WDA] 4/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.197001-197412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.197001-197412.nc
# Saved in 6.8 s
#
# [WDA] 5/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.197501-197912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.197501-197912.nc
# Saved in 6.8 s
#
# [WDA] 6/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.198001-198412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.198001-198412.nc
# Saved in 6.7 s
#
# [WDA] 7/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.198501-198912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.198501-198912.nc
# Saved in 6.7 s
#
# [WDA] 8/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.199001-199412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.199001-199412.nc
# Saved in 7.1 s
#
# [WDA] 9/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.199501-199912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.199501-199912.nc
# Saved in 7.0 s
#
# [WDA] 10/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.200001-200412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.200001-200412.nc
# Saved in 7.0 s
#
# [WDA] 11/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.200501-200912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.200501-200912.nc
# Saved in 6.8 s
#
# [WDA] 12/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.201001-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.201001-201412.nc
# Saved in 6.4 s
#
# [WDA] 13/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.201501-201912.nc
# Saved in 8.1 s
#
# [WDA] 14/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.202001-202012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/SALT/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.SALT.202001-202012.nc
# Saved in 1.5 s
#
#
# ===== Processing DIC_ALT_CO2 (WDA) =====
# [WDA] 1/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.195501-195912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.195501-195912.nc
# Saved in 7.1 s
#
# [WDA] 2/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.196001-196412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.196001-196412.nc
# Saved in 6.9 s
#
# [WDA] 3/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.196501-196912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.196501-196912.nc
# Saved in 6.9 s
#
# [WDA] 4/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.197001-197412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.197001-197412.nc
# Saved in 6.1 s
#
# [WDA] 5/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.197501-197912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.197501-197912.nc
# Saved in 7.0 s
#
# [WDA] 6/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.198001-198412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.198001-198412.nc
# Saved in 6.8 s
#
# [WDA] 7/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.198501-198912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.198501-198912.nc
# Saved in 6.8 s
#
# [WDA] 8/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.199001-199412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.199001-199412.nc
# Saved in 8.1 s
#
# [WDA] 9/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.199501-199912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.199501-199912.nc
# Saved in 6.8 s
#
# [WDA] 10/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.200001-200412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.200001-200412.nc
# Saved in 7.1 s
#
# [WDA] 11/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.200501-200912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.200501-200912.nc
# Saved in 7.0 s
#
# [WDA] 12/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.201001-201412.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BHISTsmbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.201001-201412.nc
# Saved in 6.9 s
#
# [WDA] 13/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.201501-201912.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.201501-201912.nc
# Saved in 6.6 s
#
# [WDA] 14/14
# INPUT : /mnt/lustre/proj/kimyy/tr_sysong/fld/ATM_TEST/EXP_ATM/archive/b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1/ocn/NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.202001-202012.nc
# OUTPUT: /mnt/lustre/proj/kimyy/tr_sysong/fld/regridded/WDA/NWP/ocn/DIC_ALT_CO2/regridded_NWP_b.e21.BSSP370smbb.f09_g17.assm.projdv7.3_ba-20p1.pop.h.DIC_ALT_CO2.202001-202012.nc
# Saved in 1.8 s
